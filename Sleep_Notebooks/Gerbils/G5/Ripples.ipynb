# %%
cd /mnt/Data/Workspaces/Eclipse/dataAnalysis/Sleep-current/src/
# Out:
# /mnt/Data/Workspaces/Eclipse/dataAnalysis/Sleep-current/src

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as pl
import pickle as pkl
import Recordings
import signale
import extras.trees
import os
import signale, trajectory, custom_plot,extras

# %%
animalPath = '/mnt/Data/ephysdata/Gerbils/G5/'
cscPath = '/home/chenani/dataWork/ali/gerbil5/2011-08-07/sleep3/'

# %%
ch0 = pkl.load(open(animalPath+'lfp','rb'))

# %%
f,axarr = pl.subplots(1,2,figsize = [20,10])
ch0.ripple_statistics(ax1=axarr[0],ax2=False,ax3=axarr[1],ax4=False);
f.savefig(animalPath+'plots/ripples.pdf',format = 'pdf')

# %%
pl.loglog(ch0.ripp_fft_raw[0],ch0.ripp_fft_raw[1])

# %%
ch0.sws_times
# Out:
# array([ array([  5.00000000e-01,   1.00000000e+00,   1.50000000e+00, ...,
#          1.94985000e+04,   1.94990000e+04,   1.94995000e+04]),
#        array([ 24500.5,  24501. ,  24501.5, ...,  48498.5,  48499. ,  48499.5]),
#        array([ 49000.5,  49001. ,  49001.5, ...,  50998.5,  50999. ,  50999.5]),
#        array([  56000.5,   56001. ,   56001.5, ...,  101998.5,  101999. ,
#         101999.5]),
#        array([ 105000.5,  105001. ,  105001.5, ...,  121498.5,  121499. ,
#         121499.5]),
#        array([ 125000.5,  125001. ,  125001.5, ...,  126998.5,  126999. ,
#         126999.5]),
#        array([ 133000.5,  133001. ,  133001.5, ...,  140998.5,  140999. ,
#         140999.5]),
#        array([ 142500.5,  142501. ,  142501.5, ...,  147498.5,  147499. ,
#         147499.5]),
#        array([ 149000.5,  149001. ,  149001.5, ...,  154498.5,  154499. ,
#         154499.5]),
#        array([ 168000.5,  168001. ,  168001.5, ...,  170498.5,  170499. ,
#         170499.5]),
# ...
