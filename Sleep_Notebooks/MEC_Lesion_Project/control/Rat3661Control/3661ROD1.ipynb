# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
import sys
sys.path.append('/home/chenani/ownCloud/Workspaces/Eclipse/dataAnalysis/Sleep-current/src/')
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as pl
import numpy as np
import pickle as pkl
import pandas as pd
import Recordings
import signale, trajectory
import os
from scipy.signal import argrelextrema
from scipy.signal import gaussian
from scipy.stats import pearsonr
from scipy.stats import binom_test
import seaborn as sns
import itertools as it
# Out:
# /home/chenani/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /home/chenani/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
colors = ['#FF0000', '#0000FF', '#008000', '#00FFFF', '#FF00FF', '#EE82EE',
        '#808000', '#800080', '#FF6347', '#FFFF00', '#9ACD32', '#4B0082',
        '#FFFACD', '#C0C0C0', '#A0522D', '#FA8072', '#FFEFD5', '#E6E6FA',
        '#F1FAC1', '#C5C5C5', '#A152ED', '#FADD72', '#F0EFD0', '#EEE6FF',
        '#01FAC1', '#F5F5F5', '#A152FF', '#FAFD72', '#F0EFDF', '#EEEFFF',
        '#F1FA99', '#C9C9C9', '#A152DD', '#FA5572', '#FFFFD0', '#EDD6FF']

# %%
def subsequence(sub,ref):
    '''
    A function to determine the number of specefic sequence repeated within a larger sequence.
    
    Parameters:
    sub:
    ref:
    
    
    Returns:
    idx : This an array containing the index of elements of sub in the ref! if idx is stricktly increasing the sequence sub
    is replayed whithin sequence ref!
    '''
    ref = np.array(ref)
    idx = np.array([])
    for ii in range(len(sub)):
        index = np.where(ref == sub[ii])[0]
        if index.size:
            idx = np.append(idx,index)
    idx = np.int0(idx)
    if idx.size:
        return idx, True
    else: 
        return np.array([]) , False
def locate(pattern, root=os.curdir):
    '''Locate all files matching supplied filename pattern in and below
        supplied root directory.
    '''
    for path, dirs, files in os.walk(os.path.abspath(root)):
        for filename in fnmatch.filter(files, pattern):
            yield [path,filename]
def findClosestPoint(values,array):
    values = np.array(values)
    array = np.array(array)
    idx = np.array([np.square(array - value).argmin() for value in values])
    return idx,array[idx]
def coincidence(spikes):
    spikes.burstDetector()
    spikes.MuaDetector()
    mua = spikes.MultiUnitFiring
    ccdc = []
    for k in range(len(spikes)):
        for i in range(spikes[k].spike_times.size):
            less = np.where(mua[:, 0] < spikes[k].spike_times[i])[0]  # Ripples started before spike!    
            more = np.where(mua[:, 1] > spikes[k].spike_times[i])[0]  # Ripples ended after spike!
            mua_idx = np.intersect1d(less, more)  # index of the ripple covering the spike!
            if mua_idx.size:
                ccdc.append([k, i, mua_idx])
    ccdc = np.array(ccdc)
    ccdc = ccdc[np.argsort(ccdc[:, 2])]  # sorting w.r.t ripple index  
    spikes.overlap = ccdc
def MUA(spikes):

        if not hasattr(spikes, 'overlap'):
            print 'There is no overlap detected between spikes and ripples, calculating using default arguments...'
            spikes.coincidence()
        mua = []  # Multi Unit Activity
        bursts = []  # This keeps the firing activity(>=2spikes) during ripples
        repetition = []  # Contains the number of spikes in each ripple!
        ripp_set = set(spikes.overlap[:, 2])  # Keeps the tags of ripples containing MUA! 
        
        for item in ripp_set:
            repetition.append([item, np.where(spikes.overlap[:, 2] == item)[0].size])
        repetition = np.array(repetition)
        spikes.rippleSpikeContent = repetition
        
        for item in repetition[:, 0]:
            activity_block = spikes.overlap[np.where(spikes.overlap[:, 2] == item)]
            if not activity_block[:, 0].mean() == activity_block[0, 0]:
                mua.append(activity_block)
        spikes.MultiUnitActivity = mua
def sequencing(spikes):
        '''
        This function sequences the events detected by MUA() function
        
        Parameters
        ----------
        Returns
        ----------
        sequence_1st_spike : 
        sequence_median :
        
        See also
        ----------
        coincidence, MUA
        
        Notes
        ----------
         It takes the result of MUA function as input.
        '''
        fst_spk_sq = []
        median_sq = []  # Sequences based on first spike times!
        for item in spikes.MultiUnitActivity:
            cells = set(item[:, 0])
            sequence = []
            for jtem in cells:
                row_idx = np.where(item[:, 0] == jtem)[0]
                spk_times = spikes[jtem].spike_times[item[row_idx, 1]]  # This returns the spike times of a specific cell.
                sequence.append([jtem, spk_times.min(), np.median(spk_times), spk_times.size, item[0, 2]]) #No use for the last 2! Why did i put them there?
            sequence = np.array(sequence)
            sequence = sequence[np.argsort(sequence[:, 1])]
            fst_spk_sq.append(sequence)
            sequence = sequence[np.argsort(sequence[:, 2])]
            median_sq.append(sequence)
        spikes.sequence_1st_spike = fst_spk_sq
        spikes.sequence_median = median_sq

# %%
placeCellList = '/home/chenani/dataWork/ali/MECLesion_SleepData/Marta/Rat3661/LinearTrack_03-03-15Day1/parrentData/placeCells.spk'
trajectory    = '/home/chenani/dataWork/ali/MECLesion_SleepData/Marta/Rat3661/LinearTrack_03-03-15Day1/parrentData/linearTrack_Trajectory.traj'
dataFolder    = '/home/chenani/ownCloud/IpythonNotebooks/Sleep/MEC_Lesion_Project/control/Rat3661Control/dataFiles/'

# %%
leftFields =  pkl.load(open(dataFolder+'LtemplateD1.nparr','rb'))
rightFields = pkl.load(open(dataFolder+'RtemplateD1.nparr','rb'))

# %%
pllSpikeTrain = pkl.load(open(placeCellList,'rb'))
pllSpikeTrain.changeTimeUnit('ms')
traj = pkl.load(open(trajectory,'rb'))
sleepPreTrain = pllSpikeTrain.time_slice(pllSpikeTrain.t_start,traj.t_start* 1e3)
sleepPostTrain = pllSpikeTrain.time_slice(traj.t_stop * 1e3,pllSpikeTrain.t_stop)
sleepPreTrain.timeAxis = sleepPreTrain.time_axis(1)
sleepPostTrain.timeAxis = sleepPostTrain.time_axis(1)
LTrain = pllSpikeTrain.time_slice(traj.t_start*1e3 ,traj.t_stop*1e3)
del pllSpikeTrain
animal = 'rat3906'
fileBases = ['pre','post']
sessions = [sleepPreTrain,sleepPostTrain]

# %%
LTrain.changeTimeUnit('s')
f,ax = pl.subplots(2,1,sharex=True,figsize=[30,10])
for ii,item in enumerate(rightFields):
    spk = LTrain[item]
    ax[0].scatter(spk.spike_times,np.ones(spk.spike_times.size)*(21-item),c=colors[10],s=40)
xpoints = 10*traj.places[100:,0] + np.ones(traj.places.shape[0]-100)*3
ax[0].plot(traj.times[100:],xpoints,'r',lw=1)
for ii,item in enumerate(leftFields):
    spk = LTrain[item]
    ax[1].scatter(spk.spike_times,np.ones(spk.spike_times.size)*(21-item),c=colors[11],s=40)
xpoints = 10*traj.places[100:,0] + np.ones(traj.places.shape[0]-100)*3
ax[1].plot(traj.times[100:],xpoints,'r',lw=1)
ax[0].set_xlim(4600,4700)
# Out:
# (4600, 4700)

# %%
#Interpolating trajectory
t = traj.times
It = np.arange(0,traj.times.size)
Itp = np.arange(0,traj.times.size,0.15)
tInterp = np.interp(Itp,It,t) #interpolated traj times
x = traj.places[:,0]
xp = np.interp(tInterp,t,x)       #interpolated traj Xposition
lapsDB = pkl.load(open(dataFolder+'trajectory/linearTrackD1.db','rb'))
for zaehler, st in enumerate(LTrain):
    st.traj = traj
    st.getSpikePlaces();
    st.getRunningSpikes();
# Out:
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5466.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.87 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.19 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.99 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.46 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.57 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.83 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.69 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.31 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.78 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.39 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.74 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5466.06 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5466.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5466.13 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.75 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.0 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.17 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5467.86 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.19 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.22 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.25 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.26 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.03 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.55 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.59 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.07 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.26 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.28 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.29 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.45 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.51 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.53 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.54 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.65 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.66 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.76 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.77 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.8 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.81 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.88 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.89 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.9 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.98 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.98 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.0 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.02 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.04 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.12 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.16 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.17 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.21 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.23 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.24 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.25 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.34 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.35 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.35 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.4 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.42 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.47 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.6 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.77 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.79 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.02 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.04 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.06 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.07 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.14 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.14 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.16 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.17 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.19 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.29 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.3 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.44 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.46 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.48 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.54 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.58 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.73 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.75 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.85 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.86 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.9 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.0 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.03 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.06 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.27 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.28 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.32 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.4 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.43 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.56 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.62 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.71 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.72 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.82 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.83 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.88 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.97 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.07 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.1 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.31 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.59 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.6 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.62 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.63 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.71 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.77 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.89 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.95 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.98 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.63 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.45 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.46 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5471.7 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5473.44 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5466.62 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.17 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.66 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.97 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.99 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.99 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.69 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.71 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.72 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.0 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.3 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.31 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.41 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.76 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.77 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.17 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.17 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.18 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.27 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.28 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.3 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.31 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.55 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.15 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.37 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.41 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.92 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.95 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.99 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.06 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.58 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.81 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.27 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.32 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.33 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.35 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5468.85 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.67 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.69 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.82 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.06 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.07 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.16 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.27 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.31 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.44 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.86 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.92 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.96 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.03 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.49 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.75 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.85 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.91 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.56 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5478.09 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.18 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.49 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.52 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.02 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.03 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.12 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.13 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.25 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.48 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.59 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.67 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.78 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.79 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.84 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.3 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.34 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.37 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.38 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.39 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.42 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.54 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5466.09 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.49 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.49 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.61 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.74 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5473.98 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.0 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.26 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.27 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.48 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.08 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.31 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.33 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.51 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5469.7 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.1 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.44 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.45 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.48 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.52 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.52 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.53 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5466.19 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.67 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.68 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.68 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.71 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.71 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.78 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.78 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.79 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.95 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.53 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.54 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.47 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.2 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.2 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5468.47 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.48 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.02 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.03 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.04 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.15 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.28 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.65 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.65 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.5 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.44 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5473.68 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.29 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.47 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.75 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.52 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.72 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.75 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5480.15 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5476.77 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.62 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.32 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.41 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.42 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.49 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5474.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.73 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5466.16 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5466.18 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5466.21 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5466.23 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5466.33 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5468.8 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.82 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.97 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5478.17 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5469.91 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.94 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.95 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.95 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5470.97 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.3 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.34 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.57 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.84 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.87 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.88 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.96 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.09 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.1 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.38 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.18 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.54 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.57 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5467.26 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5467.27 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5467.28 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5467.39 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5467.64 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.63 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.87 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5469.87 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.0 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.04 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.29 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.44 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.44 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.72 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.72 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5472.11 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5474.1 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.93 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.18 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.28 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.29 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.54 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.29 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.54 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.59 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.6 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5476.56 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.62 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.63 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.72 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5471.69 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5471.91 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.63 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.79 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5475.86 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.57 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.78 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.79 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5477.02 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.19 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.8 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.86 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5478.97 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.72 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: at time 5471.01 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.3 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5476.77 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5479.53 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: at time 5480.51 there was a spike after the                    end of the trajectory 5465.938242 !
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!
# NOTE: Using linear interpolation to get the places.
# WARNING: Calculating without spike phases! If spike phases are needed caluculate them before!
# WARNING: Calculating without spike head directions! If spike head directions are needed caluculate them before!

# %%
LTrain.changeTimeUnit('ms')
LTrain.binwidth = 1
LTrain.calcTimeAxis()
tV,speed = traj.getSpeed()
stationary = np.where(speed < 0.1)[0]
takeoffs = tV[np.where(np.diff(stationary)>70)[0]]
takeoffs.size
# Out:
# 129

# %%
lapsDB.shape
# Out:
# (151, 3)

# %%
f,ax = pl.subplots(1,1,figsize=[30,8])
restPeriods = []
for ii,lap in enumerate(lapsDB):
    lapT = tInterp[lap[0]:lap[1]]*1e3
    lapX = xp[lap[0]:lap[1]]
    ax.plot(lapT,(lapX - np.ones(lapX.size)*0.15)/1.8)
    if ii <= 149:
        if np.abs(tInterp[lap[1]]-tInterp[lapsDB[ii+1][0]]) < 25:
            #print (tInterp[lap[1]]-tInterp[lapsDB[ii+1][0]])
            ax.axvspan(tInterp[lap[1]]*1e3,tInterp[lapsDB[ii+1][0]]*1e3,alpha=0.5)
            restPeriods.append([tInterp[lap[1]]*1e3,tInterp[lapsDB[ii+1][0]]*1e3])
    #for item in takeoffs[::-10]:
    #    ax[0].axvline(item*1e3)
for ii,item in enumerate(leftFields):
    spk = LTrain[item]
    ax.scatter(spk.spike_times,np.ones(spk.spike_times.size)*(float(ii)/leftFields.size),c=colors[13],s=40)
ax.set_xlim(4.4e6,4.669e6)
restPeriods = np.array(restPeriods)

# %%
LTrain.changeTimeUnit('ms')
LTrain.binwidth = 1
LTrain.calcTimeAxis()
hst = []
for unit in LTrain:
    hst.append(np.histogram(unit.spike_times,LTrain.timeAxis)[0])
hst = np.array(hst)
unitSum = hst.sum(axis=0)

# %%
f,ax = pl.subplots(1,1,figsize=[30,8])
K1 = gaussian(200,25)
K2 = gaussian(100,30)
MUA1 = np.convolve(unitSum,K1,'same')
MUA2 = np.convolve(unitSum,K2,'same')
ax.plot(traj.times*1e3,8*traj.places[:,0]-5)
ax.plot(LTrain.timeAxis[:-1],MUA1,lw=1)
ax.plot(LTrain.timeAxis[:-1],MUA2,lw=1)
ax.axhspan(MUA2.mean()+MUA1.std(),MUA2.mean()+3*MUA1.std(),alpha = 0.3)
ax.set_xlim(4.4e6,4.669e6)
# Out:
# (4400000.0, 4669000.0)

# %%
canEv = []
peakTimes = []
for ii,rp in enumerate(restPeriods):
    validIdx = np.intersect1d(np.where(LTrain.timeAxis > rp[0])[0],np.where(LTrain.timeAxis < rp[1])[0])
    restMUA = MUA2[validIdx]
    restTimeAxis = LTrain.timeAxis[validIdx]
    m3sd = restMUA.mean() + 3*restMUA.std()
    msd = restMUA.mean() + restMUA.std()
    peaksIdx = argrelextrema(restMUA, np.greater)[0] #Peaks in MUA of selected rest.
    SigPeaksIndex = np.where(restMUA[peaksIdx] > m3sd)[0]
    peakTimes.extend(restTimeAxis[peaksIdx][SigPeaksIndex])
#pl.plot(LTrain.timeAxis[:-1],MUA2)
print SigPeaksIndex
# Out:
# [75]

# %%
peakTimes = np.array(peakTimes)
#closePeaksIdx = np.where(np.diff(peakTimes) < 200)[0]
#peakTimes = np.delete(peakTimes,closePeaksIdx)

# %%
f,ax = pl.subplots(2,1,sharex=True,figsize=[30,10])
restPeriods = []
for ii,lap in enumerate(lapsDB):
    lapT = tInterp[lap[0]:lap[1]]*1e3
    lapX = xp[lap[0]:lap[1]]
    ax[0].plot(lapT,lapX - np.ones(lapX.size)*0.8)
    ax[1].plot(lapT,lapX - np.ones(lapX.size)*0.8)
for tt in peakTimes:
    ax[0].axvline(tt,linewidth=1)
    ax[1].axvline(tt,linewidth=1)
for ii,item in enumerate(leftFields):
    spk = LTrain[item]
    ax[0].scatter(spk.spike_times,np.ones(spk.spike_times.size)*(float(ii)/leftFields.size),c=colors[2],s=40)
for ii,item in enumerate(rightFields):
    spk = LTrain[item]
    ax[1].scatter(spk.spike_times,np.ones(spk.spike_times.size)*(float(ii)/rightFields.size),c=colors[2],s=40)
ax[0].set_xlim(4.4e6,4.669e6)
# Out:
# (4400000.0, 4669000.0)

# %%
MUApeaks = []
for tP in peakTimes:
    Ncells = 0
    idx = np.where(LTrain.timeAxis == tP)[0][0]
    ii = idx-250
    jj = idx+250
    ti = LTrain.timeAxis[ii]
    tf = LTrain.timeAxis[jj]
    for spk in LTrain:
        inWindowSpikes = np.logical_and(spk.spike_times > ti,spk.spike_times < tf)
        if inWindowSpikes.sum():
            Ncells +=1
    if Ncells > 4:
        MUApeaks.append(tP)
MUApeaks = np.array(MUApeaks)

# %%
corrBins = np.arange(-1.05,1.15,0.05)
f,(ax,bx,cx) = pl.subplots(1,3,figsize=[30,7])
Pr = []
pR = []
pL = []
for tP in MUApeaks[:]:
    idx = np.where(LTrain.timeAxis == tP)[0][0]
    ii = idx-150
    jj = idx+150
    ti = LTrain.timeAxis[ii]
    tf = LTrain.timeAxis[jj]
    evIds = []
    for cellID in LTrain.id_list:
        spk = LTrain[cellID]
        inWindowSpikes = np.logical_and(spk.spike_times > ti,spk.spike_times < tf)
        evIds.append(spk.spike_times[inWindowSpikes].mean())
    Npcells = np.logical_not(np.isnan(evIds)).sum()
    timeSortedIds =  np.argsort(evIds)[:Npcells]
    Lsub = subsequence(timeSortedIds,leftFields)[0]
    Rsub = subsequence(timeSortedIds,rightFields)[0]
    if Lsub.size > 2:
        Lr = pearsonr(Lsub,sorted(Lsub))[0]
    else: 
        Lr = 100
    if Rsub.size > 2:
        Rr = pearsonr(Rsub,sorted(Rsub))[0]
    else:
        Rr = 100
    LRcorr = np.array([Lr,Rr])
    Pr.append(LRcorr[np.argmax(np.abs(LRcorr))])
    pR.append(Rr)
    pL.append(Lr)
ax.hist([pR],corrBins,label=['Right'],color=sns.color_palette('deep')[0]);
bx.hist([pL],corrBins,label=['Left'],color=sns.color_palette('deep')[2]);
cx.hist([Pr],corrBins,label=['All'],color=sns.color_palette('deep')[1]);
ax.set_xlim([-1,1])
ax.legend(loc=2);
bx.legend(loc=2);
cx.legend(loc=2);
# Out:
# /home/chenani/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
pkl.dump(Pr,open(dataFolder + '3661D1All.lro','wb'),pkl.HIGHEST_PROTOCOL)
pkl.dump(pL,open(dataFolder + '3661D1Left.lro','wb'),pkl.HIGHEST_PROTOCOL)
pkl.dump(pR,open(dataFolder + '3661D1Right.lro','wb'),pkl.HIGHEST_PROTOCOL)

# %%
len(Pr)
# Out:
# 972

# %%
peakProfs = np.zeros([MUApeaks.size,500])
cutThresh = msd
MUAtimes = []
idxPre = 0
for kkk,tP in enumerate(MUApeaks[:]):
    idx = np.where(LTrain.timeAxis == tP)[0][0]
    idxMin = np.where(np.square(MUA1[idxPre:idx]-cutThresh)<1e-2)[0][-1]
    idxMAX = np.where(np.square(MUA1[idx:]-cutThresh)<1e-2)[0][0]
    timeSpan = idxMAX+idx-idxPre-idxMin
    #idxPre = idx+idxMAX-2
    #print idxPre,idx
    
    if timeSpan>20 and timeSpan<500:
        MUAtimes.append([LTrain.timeAxis[idxMin],LTrain.timeAxis[idx+idxMAX],tP])
        peakProfs[kkk,:]+=MUA1[idx-250:idx+250]
countBins = np.linspace(0-0.5,len(MUAtimes)-0.5,len(MUAtimes)+1)
counts = np.histogram(np.where(np.diff(MUAtimes,axis=0)==0)[0],countBins)[0]
duplicates = np.where(counts==2)[0]
#print duplicates,duplicates.size
#duplicates = np.where(np.diff(MUAtimes,axis=0)==0)[0]
####print duplicates,duplicates.size
#duplicates = np.unique(duplicates)
####print duplicates,duplicates.size
uniques = np.array([item for item in range(len(MUAtimes)) if item not in duplicates])
MUAtimes =  np.array([MUAtimes[idx] for idx in uniques])
sns.tsplot(peakProfs,time=np.linspace(-250,250,500))
pl.axhspan(0.6*msd,0.6*m3sd,alpha=0.3)
pl.plot(np.linspace(-100,100,200),7.5*K1,'r--')
pl.axvspan(-2.3548*12.5,2.3548*12.5,alpha=0.2)
print 60/2.3548,duplicates.size,uniques.size,MUApeaks.size
# Out:
# 25.479870902 533 335 972
# /home/chenani/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
corrBins = np.arange(-1.05,1.15,0.05)
corrBinsCenters = (corrBins+0.025)[:-1]
f,(ax,bx,cx) = pl.subplots(1,3,figsize=[30,7])
Pr = []
pR = []
pL = []
fghj = np.zeros([len(MUAtimes),11])
for kkk,item in enumerate(MUAtimes):
    ti=item[0]
    tf=item[1]
    tP=item[2]
    evIds = []
    for cellID in LTrain.id_list:
        spk = LTrain[cellID]
        inWindowSpikes = np.logical_and(spk.spike_times > ti,spk.spike_times < tf)
        evIds.append(spk.spike_times[inWindowSpikes].mean())
    Npcells = np.logical_not(np.isnan(evIds)).sum()
    timeSortedIds =  np.argsort(evIds)[:Npcells]
    #print timeSortedIds.size
    Lsub = subsequence(timeSortedIds,leftFields)[0]
    Rsub = subsequence(timeSortedIds,rightFields)[0]
    #print Lsub,Rsub
    if Lsub.size>3:
        Lr = pearsonr(range(Lsub.size),np.argsort(Lsub))[0]#pearsonr(Lsub,sorted(Lsub))[0]
    else: 
        Lr = 100#np.nan
    if Rsub.size>3:
        Rr = pearsonr(range(Rsub.size),np.argsort(Rsub))[0]#pearsonr(Rsub,sorted(Rsub))[0]
    else:
        Rr = 100#np.nan
    LRcorr = np.array([Lr,Rr])
    #if LRcorr.sum()<200:
        #print LRcorr, np.argsort(Rsub)
    Pr.append(LRcorr[np.argmax(np.abs(LRcorr))])
    pR.append(Rr)
    pL.append(Lr)
    fghj[kkk,:]+= np.array([ti,tf,tP,timeSortedIds.size,Lsub.size,Rsub.size,Lr,Rr,1.0,1.0,3661])
ax.hist([pR],corrBins,label=['Right'],color=sns.color_palette('deep')[0]);
bx.hist([pL],corrBins,label=['Left'],color=sns.color_palette('deep')[2]);
cx.hist([Pr],corrBins,label=['All'],color=sns.color_palette('deep')[1]);
ax.set_xlim([-1,1])
ax.legend(loc=2);
bx.legend(loc=2);
cx.legend(loc=2);
f,(ax,bx,cx) = pl.subplots(1,3,figsize=[30,7])
ax.hist(1e2*fghj[:,3]/LTrain.id_list.size,20);
bx.hist(1e2*fghj[:,4]/LTrain.id_list.size,20);
cx.hist(1e2*fghj[:,5]/LTrain.id_list.size,20);
###################################
#####Saving DB#####################

df = pd.DataFrame(fghj,columns=['ti','tf','tp','tSub','lSub','rSub','Lcorr','Rcorr','Lpv','Rpv','animal_ID'])
df = df.replace(100,np.nan)
roDB = df.copy()
df.to_pickle(dataFolder+'awakeReplays-3661-D1.db')

# %%
surrProbs = []
for n in range(4,11):
    crr = pkl.load(open('/home/chenani/ownCloud/IpythonNotebooks/Sleep/MEC_Lesion_Project/RankOrder/corr'+str(n)+'.crr','rb'))
    hst = np.histogram(crr,corrBins,normed=True)[0]
    surrProbs.append(hst)
#################################
for n in range(4,11):
    print n
    print '----------------'
    dfLsub = df[df.lSub==n]
    dfRsub = df[df.rSub==n]
    hstL = np.histogram(dfLsub.Lcorr,corrBins)[0]
    hstR = np.histogram(dfRsub.Rcorr,corrBins)[0]
    for item in np.where(hstL)[0]:
        #print hstL[item],corrBinsCenters[item]
        p_value = binom_test(hstL[item],hstL.sum(),surrProbs[n-4][item]*0.05)
        if p_value < 0.05:
            idxs = np.where(np.abs(findClosestPoint(dfLsub.Lcorr,corrBinsCenters)[1]- corrBinsCenters[item])<0.01)[0]
            locs = dfLsub.index[idxs]
            df.Lpv[locs] += (p_value-1)
            #print p_value,dfLsub.Lcorr.loc[locs]
    #print '####################'
    for item in np.where(hstR)[0]:
        #print hstR[item],corrBinsCenters[item]
        p_value = binom_test(hstR[item],hstR.sum(),surrProbs[n-4][item]*0.05)
        if p_value < 0.05:
            idxs = np.where(np.abs(findClosestPoint(dfRsub.Rcorr,corrBinsCenters)[1]- corrBinsCenters[item])<0.01)[0]
            locs = dfRsub.index[idxs]
            df.Rpv[locs] += (p_value-1)
            #print p_value

    print '##############################################################################'
###################################################################################
print '10++'
dfLsub = df[df.lSub>10]
dfRsub = df[df.rSub>10]
hstL = np.histogram(dfLsub.Lcorr,corrBins)[0]
hstR = np.histogram(dfRsub.Rcorr,corrBins)[0]
for item in np.where(hstL)[0]:
    #print hstL[item],corrBinsCenters[item]
    p_value = binom_test(hstL[item],hstL.sum(),surrProbs[-1][item]*0.05)
    if p_value < 0.05:
        #print corrBinsCenters[item],p_value
        idxs = np.where(np.abs(findClosestPoint(dfLsub.Lcorr,corrBinsCenters)[1]- corrBinsCenters[item])<0.01)[0]
        locs = dfLsub.index[idxs]
        df.Lpv[locs] += (p_value-1)
print '####################'
for item in np.where(hstR)[0]:
    #print hstR[item],corrBinsCenters[item]
    p_value = binom_test(hstR[item],hstR.sum(),surrProbs[-1][item]*0.05)
    if p_value < 0.05:
        idxs = np.where(np.abs(findClosestPoint(dfRsub.Rcorr,corrBinsCenters)[1]- corrBinsCenters[item])<0.01)[0]
        locs = dfRsub.index[idxs]
        df.Rpv[locs] += (p_value-1)
# Out:
# 4
# ----------------
# ##############################################################################
# 5
# ----------------
# ##############################################################################
# 6
# ----------------
# ##############################################################################
# 7
# ----------------
# ##############################################################################
# 8
# ----------------
# ##############################################################################
# 9
# ----------------
# ##############################################################################
# 10
# ----------------
# ##############################################################################
# 10++
# ####################

# %%
fig,(ax,bx) = pl.subplots(1,2,figsize=[30,10],sharex=True)
ax.hist([df[df.Lpv==1].Lcorr,df[df.Lpv!=1].Lcorr],corrBins,label=[],normed=False,stacked=True);
bx.hist([df[df.Rpv==1].Rcorr,df[df.Rpv!=1].Rcorr],corrBins,label=[],normed=False,stacked=True);
ax.set_xlim(-1,1)
pl.legend()
#############################
nT = 0
nS = 0
for n in range(4,20):
    dbN = df[df.lSub==n]
    if 1:#dbN[dbN.Lpv<1].shape[0]:
        nT+=dbN.shape[0]
        nS+=dbN[dbN.Lpv<0.05].shape[0]
        print n,dbN.shape[0],dbN[dbN.Lpv<0.5].shape[0]
        print binom_test(dbN[dbN.Lpv<0.5].shape[0],dbN.shape[0],5e-2)
print '------------------------'
print '########################'
for n in range(4,20):
    dbN = df[df.rSub==n]
    if 1:#dbN[dbN.Rpv<1].shape[0]:
        nT+=dbN.shape[0]
        nS+=dbN[dbN.Rpv<0.05].shape[0]
        print n,dbN.shape[0],dbN[dbN.Rpv<0.5].shape[0]
        print binom_test(dbN[dbN.Rpv<0.5].shape[0],dbN.shape[0],5e-2)
print '------------------------'
print nT,nS,binom_test(nS,nT,0.05)
# Out:
# 4 74 0
# 0.0538335063704
# 5 78 0
# 0.0341042501953
# 6 41 13
# 5.7095907063e-08
# 7 31 7
# 0.000708938817183
# 8 8 4
# 0.000371751367188
# 9 15 7
# 3.51819989673e-06
# 10 6 2
# 0.032773828125
# 11 4 0
# 1.0
# 12 0 0
# 1.0
# 13 1 0
# 1.0
# 14 1 0
# 1.0
# 15 0 0
# 1.0
# 16 0 0
# 1.0
# 17 0 0
# 1.0
# 18 0 0
# 1.0
# 19 0 0
# 1.0
# ------------------------
# ########################
# 4 70 11
# 0.000684364703119
# 5 61 10
# 0.000843560073253
# 6 46 11
# 1.27400486332e-05
# 7 23 3
# 0.105174326928
# 8 13 3
# 0.0245078417459
# 9 2 1
# 0.0975
# 10 5 2
# 0.0225925
# 11 2 1
# 0.0975
# 12 1 0
# 1.0
# 13 0 0
# 1.0
# 14 0 0
# 1.0
# 15 0 0
# 1.0
# 16 0 0
# 1.0
# 17 0 0
# 1.0
# 18 0 0
# 1.0
# 19 0 0
# 1.0
# ------------------------
# 482 75 4.92952400359e-18

# %%
binwidth = 0.1
A = np.linspace(0,1.,1.0/binwidth+1)
binwidth = np.diff(A)[0]
corrBinsCenters = np.union1d(-1*A,A)
corrBins = corrBinsCenters-binwidth/2
corrBins = np.insert(corrBins,[corrBins.size],[corrBins[-1]+binwidth])
##########################################
surrProbs = []
for n in range(4,11):
    crr = pkl.load(open('/home/chenani/ownCloud/IpythonNotebooks/Sleep/MEC_Lesion_Project/RankOrder/corr'+str(n)+'.crr','rb'))
    hst = np.histogram(crr,corrBins,normed=True)[0]
    surrProbs.append(hst)
#################################
idx = [findClosestPoint([0.025],binwidth*np.cumsum(surrProbs[n-5]))[0] for n in range(5,11)]
SigCorrMin = [np.abs(corrBinsCenters[ii+1][0]) for ii in idx]
for idx,row in roDB.iterrows():
    if row.lSub>4:
        if np.abs(row.Lcorr) > SigCorrMin[min(int(row.lSub - 5),len(SigCorrMin)-1)]:
            row.Lpv-=0.96
    if row.rSub>4:
        if np.abs(row.Rcorr) > SigCorrMin[min(int(row.rSub - 5),len(SigCorrMin)-1)]:
            row.Rpv-=0.96
            
nT = 0
nS = 0
for n in range(5,20):
    dbN = roDB[roDB.lSub==n]
    if 1:#dbN[dbN.Lpv<1].shape[0]:
        nT+=dbN.shape[0]
        nS+=dbN[dbN.Lpv<0.05].shape[0]
        print n,dbN.shape[0],dbN[dbN.Lpv<0.5].shape[0]
        print binom_test(dbN[dbN.Lpv<0.5].shape[0],dbN.shape[0],5e-2)
print '------------------------'
print '########################'
for n in range(5,20):
    dbN = roDB[roDB.rSub==n]
    if 1:#dbN[dbN.Rpv<1].shape[0]:
        nT+=dbN.shape[0]
        nS+=dbN[dbN.Rpv<0.05].shape[0]
        print n,dbN.shape[0],dbN[dbN.Rpv<0.5].shape[0]
        print binom_test(dbN[dbN.Rpv<0.5].shape[0],dbN.shape[0],5e-2)
print '------------------------'
print nT,nS,binom_test(nS,nT,0.05)
# Out:
# 5 78 1
# 0.188578322653
# 6 41 5
# 0.0525343360166
# 7 31 2
# 0.667309915888
# 8 8 3
# 0.00578821792969
# 9 15 2
# 0.170952535504
# 10 6 2
# 0.032773828125
# 11 4 0
# 1.0
# 12 0 0
# 1.0
# 13 1 0
# 1.0
# 14 1 0
# 1.0
# 15 0 0
# 1.0
# 16 0 0
# 1.0
# 17 0 0
# 1.0
# 18 0 0
# 1.0
# 19 0 0
# 1.0
# ------------------------
# ########################
# 5 61 5
# 0.232720561841
# 6 46 5
# 0.0786118628818
# 7 23 2
# 0.320579555555
# 8 13 6
# 1.97497136832e-05
# 9 2 0
# 1.0
# 10 5 2
# 0.0225925
# 11 2 1
# 0.0975
# 12 1 0
# 1.0
# 13 0 0
# 1.0
# 14 0 0
# 1.0
# 15 0 0
# 1.0
# 16 0 0
# 1.0
# 17 0 0
# 1.0
# 18 0 0
# 1.0
# 19 0 0
# 1.0
# ------------------------
# 338 36 2.53445338189e-05

# %%
ss = subsequence([1,7,100,13,2,221],[2,1,7,13,15])
ss
# Out:
# (array([1, 2, 3, 0]), True)

# %%
pearsonr(np.arange(ss[0].size),np.argsort(ss[0]))
# Out:
# (0.40000000000000002, 0.59999999999999976)

# %%
np.argsort(ss[0]),np.arange(ss[0].size)
# Out:
# (array([0, 3, 1, 2]), array([0, 1, 2, 3]))
