# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
import sys
sys.path.append('/mnt/Data/ownCloud/Workspaces/Eclipse/dataAnalysis/Sleep-current/src/')
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as pl
import pickle as pkl
import Recordings
import signale,trajectory
import extras.trees
import os,sys
import fnmatch
import colormaps as cmaps
import seaborn as sns
import scipy.signal as scsig
# Out:
# /home/chenani/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /home/chenani/anaconda/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/chenani/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
def locate(pattern, root=os.curdir):
    '''
    Locate all files matching supplied filename pattern in and below
        supplied root directory.
    Parameters
    ----------
        pattern : string
            A string representing pattern you want to look for in the path.
        root : string
            contains the path address you want to look trough!
    Returns
    ----------
        Array of strings consist of two column, first contains the path and second the file names that matched 
        the desired pattern.
    '''
    for path, dirs, files in os.walk(os.path.abspath(root)):
        for filename in fnmatch.filter(files, pattern):
            yield [path,filename]
def ncs_loader(fileName):
    ncs_dtype = np.dtype([
        ('qTimeStamps'  ,     '<u8'),
        ('ChannelNumber'  , '<u4'),
        ('SampleFreq',      '<u4'),
        ('NumValidSamples', '<u4'),
        ('Samples'  ,       '<i2',(512,)),
    ])
    return np.memmap(fileName,dtype=ncs_dtype,offset=(16 * 2**10))
def nvt_loader(filename):
    """ 
    Memory map the Neuralynx .nvt format
    Fields
    -------
    swstx
    swid
    sw_data_size
    qTimeStamps       Cheetah timestamp for this record. This value is in microseconds.
    dwpoints          Points with the color bitfield values for this record.This is a 400
                      element array.  See Video Tracker in reference. 
    sncrc
    dnextracted_x     Extracted X location of the target being tracked. 
    dnextracted_y     Extracted Y location of the target being tracked.
    dnextracted_angle The calculated head angle in degrees clockwise from the positive Y
                      axis. Zero will be assigned if angle tracking is disabled.
    dnTargets         Colored targets using the samebitfield format used by the dwPoints array.
                      Instead of transitions, the bitfield indicates the colors that make up 
                      each particular target and the center point of that target.  This is a 50
                      element array sorted by size from largest (index 0) to smallest(index 49).
                      A target value of 0 means that no target is present in thatindex location.
                      See Video Tracker Bitfield Information in reference. 
    
    Reference:
    ----------
        http://neuralynx.com/software/NeuralynxDataFileFormats.pdf
    """ 
    nev_dtype = np.dtype([
        ('swstx'              , '<i2'),
        ('swid'               , '<i2'),
        ('sw_data_size'       , '<i2'),
        ('qTimeStamps'        , '<u8'),
        ('dwPoints'           , '<u4',(400,)),
        ('sncrc'              , '<i2'),
        ('dnextracted_x'      , '<i4'),
        ('dnextracted_y'      , '<i4'),
        ('dnextracted_angle'  , '<i4'),
        ('dnTargets'          , '<i4',(50,)),
    ])
    return np.memmap(filename, dtype=nev_dtype, mode='readwrite',
       offset=(16 * 2**10))
def nev_loader(filename):
    """ Memory map the Neuralynx .nev format """ 
    nev_dtype = np.dtype([
        ('nstx'           , '<i2'),
        ('npkt_id'        , '<i2'),
        ('npkt_data_size' , '<i2'),
        ('qTimeStamps'    , '<u8'),
        ('nevent_id'      , '<i2'),
        ('nttl'           , '<i2'),
        ('ncrc'           , '<i2'),
        ('ndummy1'        , '<i2'),
        ('ndummy2'        , '<i2'),
        ('dnExtra'        , '<i4',(8,)),
        ('String'         , '<S128')
    ])
    return np.memmap(filename, dtype=nev_dtype, mode='r',
       offset=(16 * 2**10))
###################################################### initialization
###################################################### Parameters
expType = 'real'
prefix = 'TT'
suffix = ''
noSpeck = False
onlyRunning = True
showHeadDir = False
saveFigs = True
useRecommended = False
TTName = '.t'

# initialize in order to make them available globally
spikes=[]
ID=-1
stList=signale.spikezugList(t_start=None, t_stop=None, dims=[2])
eventData = None

cwd=os.getcwd()


###################################################### functions

def getData(folderName):
    global spikes, ID, eventData

    if os.path.isdir(folderName):
        dirList=os.listdir(folderName)
        os.chdir(folderName)
    else:
        dirList = [folderName]
    for item in sorted(dirList):
        if os.path.isfile(item):
            if (TTName.__class__ == list and item in TTName) or\
                    (TTName.__class__ == str and item.endswith(suffix+'.t') and item.startswith(prefix)):
                print 'loading', item , 'from folder: '+'/'.join(folderName.split('/')[-3:])
                spikes = signale.load_tFile(item, showHeader=False)
                ID += 1
                stList.__setitem__(ID, spikes)
                stList.addTags(ID, file=item, dir=folderName)
            
        elif os.path.isdir(item):
            getData(item)
    os.chdir('..')

# %%
WorkPath = '/mnt/Data/ownCloud/IpythonNotebooks/Sleep/MEC_Lesion_Project/PCA_MEC/'
experimentFolder = '/home/chenani/dataWork/ali/MECLesion_SleepData/Marta/Rat3906/LinearTrack_06-03-16_Day4/'
parrentFolder = experimentFolder + 'parrentData/'

# %%
getData(parrentFolder)
lfpList = sorted([os.path.join(item[0],item[1]) for item in locate('*CSC6-*.lfp',experimentFolder)])
lfpPRE,lfpTRACK,lfpPOST =[pkl.load(open(lfpFile,'rb')) for lfpFile in lfpList]
for lfp in [lfpPRE,lfpTRACK,lfpPOST]:
    lfp.filter(5,10)
# Out:
# loading TT12_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_05.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_06.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_07.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_08.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_09.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_10.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_11.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_12.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_13.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT12_14.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_05.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_06.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_07.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_09.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT1_10.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT2_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT2_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT2_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT2_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT2_05.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT2_06.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT2_07.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_05.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_06.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_07.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_08.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_09.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_10.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT3_11.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT4_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT5_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT5_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT5_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT5_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT5_05.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT6_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT6_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT6_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT6_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT7_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT7_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT7_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT7_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_05.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_06.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_07.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_08.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_09.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_10.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_11.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_12.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_13.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_14.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT8_15.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_01.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_02.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_03.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_04.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_05.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_06.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_07.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_08.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_09.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_10.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_11.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_12.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_13.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_14.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_15.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_16.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_17.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_18.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_19.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_20.t from folder: LinearTrack_06-03-16_Day4/parrentData/
# loading TT9_21.t from folder: LinearTrack_06-03-16_Day4/parrentData/

# %%
pre,track,post  = [stList.time_slice(lfp.timeAxis[0],lfp.timeAxis[-1]) for lfp in [lfpPRE,lfpTRACK,lfpPOST]]
ExperimentSessions = [pre,track,post]

thetaTimeBinEdges = []
for lfp in [lfpPRE,lfpTRACK,lfpPOST]:
    thetaTimeBinEdges.append(lfp.timeAxis[scsig.argrelmax(lfp.signal_filtered)[0]])

nulIdx1 = np.where((np.array([item.spike_times.size for item in pre])==0))[0]
nulIdx2 = np.where((np.array([item.spike_times.size for item in track])==0))[0]
nulIdx3 = np.where((np.array([item.spike_times.size for item in post])==0))[0]
nullList= np.union1d(np.union1d(nulIdx1,nulIdx2),nulIdx3)
for null in nullList:
    print stList.tags[null]

# %%
#####PCA with fixed time bins of width 100 ms
corrMatrices = []
Qs = []
eigVals = []
eigVecs = []
Ps = []
for ii,item in enumerate(ExperimentSessions):
    print ii
    Q,C,l,V,P = item.PCA()
    corrMatrices.append(C)
    Qs.append(Q)
    eigVals.append(l)
    eigVecs.append(V)
    Ps.append(P)
#####PCA with time bins defined by theta periods
ThetaCorrMatrices = []
ThetaQs = []
ThetaEigVals = []
ThetaEigVecs = []
ThetaPs = []
for ii,item in enumerate(ExperimentSessions):
    print ii
    Q,C,l,V,P = item.PCA(bins=thetaTimeBinEdges[ii])
    ThetaCorrMatrices.append(C)
    ThetaQs.append(Q)
    ThetaEigVals.append(l)
    ThetaEigVecs.append(V)
    ThetaPs.append(P)
# Out:
# 0
# bin edges are caclulated with width 100 ms
# 1
# bin edges are caclulated with width 100 ms
# 2
# bin edges are caclulated with width 100 ms
# 0
# time bin edges are proovided by user.
# 1
# time bin edges are proovided by user.
# 2
# time bin edges are proovided by user.

# %%
N = stList.id_list.size*1.0
lMax = []
lMin = []
TlMax = []
TlMin = []
for q,Tq in zip(Qs,ThetaQs):
    lMax.append(np.math.pow(1 + np.math.sqrt(N/q.size),2))
    lMin.append(np.math.pow(1 - np.math.sqrt(N/q.size),2))
    TlMax.append(np.math.pow(1 + np.math.sqrt(N/Tq.size),2))
    TlMin.append(np.math.pow(1 - np.math.sqrt(N/Tq.size),2))
TW_limit =  np.math.pow(N,-0.6666666666)
print lMax,lMin,TW_limit
# Out:
# [1.0105383694096055, 1.0148090484936876, 1.0103803247371228] [0.9895168685278098, 0.9852998009675078, 0.9896732730117715] 0.0494279279849

# %%
from scipy.cluster.hierarchy import fcluster,linkage,dendrogram
CCC = []
for C in ThetaCorrMatrices:
    Z = linkage(C,method='ward')#,metric='')
    order = dendrogram(Z,no_plot=True)['leaves']
    Csort = np.zeros(C.shape)
    for ii,idx in enumerate(order):
        Csort[ii,:]+=C[idx,order]
    CCC.append(Csort)
N = int(N)
sns.set_style('white')
f,axarr = pl.subplots(1,3,figsize=[15,5],sharex=True,sharey=True)
im1 = axarr[0].pcolormesh(CCC[0] - np.identity(N),cmap="RdBu_r");
im2 = axarr[1].pcolormesh(CCC[1] - np.identity(N),cmap="RdBu_r");
im3 = axarr[2].pcolormesh(CCC[2] - np.identity(N),cmap="RdBu_r");
axarr[0].set_xlim(0,N)
axarr[0].set_ylim(0,N)
# Out:
# (0, 91)

# %%
sns.set_style('white')
f,axarr = pl.subplots(2,3,figsize=[30,20])
im1 = axarr[0,0].pcolor(corrMatrices[0] - np.identity(N),cmap='magma');
im2 = axarr[0,1].pcolor(corrMatrices[1] - np.identity(N),cmap='magma');
im3 = axarr[0,2].pcolor(corrMatrices[2] - np.identity(N),cmap='magma');
im4 = axarr[1,0].pcolor(ThetaCorrMatrices[0] - np.identity(N),cmap=cmaps.magma);
im5 = axarr[1,1].pcolor(ThetaCorrMatrices[1] - np.identity(N),cmap=cmaps.magma);
im6 = axarr[1,2].pcolor(ThetaCorrMatrices[2] - np.identity(N),cmap=cmaps.magma)
'''
ax1.set_title('Sleep PRE')
ax2.set_title('LinearTrack')
ax3.set_title('Sleep POST')
#pl.colorbar(im3);
'''
pl.tight_layout()

# %%
f,axarr = pl.subplots(2,3,figsize=[30,20],sharey=True)
axarr[0,0].scatter(range(eigVals[0].size),eigVals[0],s=75)
axarr[0,0].axhline(lMax[0]+TW_limit,color = 'r',linestyle='--')
axarr[0,1].scatter(range(eigVals[1].size),eigVals[1],s=75)
axarr[0,1].axhline(lMax[1]+TW_limit,color = 'r',linestyle='--')
axarr[0,2].scatter(range(eigVals[2].size),eigVals[2],s=75)
axarr[0,2].axhline(lMax[2]+TW_limit,color = 'r',linestyle='--')
############
axarr[1,0].scatter(range(ThetaEigVals[0].size),ThetaEigVals[0],s=75)
axarr[1,0].axhline(TlMax[0]+TW_limit,color = 'r',linestyle='--')
axarr[1,1].scatter(range(eigVals[1].size),ThetaEigVals[1],s=75)
axarr[1,1].axhline(TlMax[1]+TW_limit,color = 'r',linestyle='--')
axarr[1,2].scatter(range(eigVals[2].size),ThetaEigVals[2],s=75)
axarr[1,2].axhline(TlMax[2]+TW_limit,color = 'r',linestyle='--')
'''
ax1.set_ylabel('EigVals PRE')
ax1.set_xlabel('#')
ax2.set_ylabel('EigVals LinearTrack')
ax2.set_xlabel('#')
ax3.set_ylabel('EigVals POST')
ax3.set_xlabel('#')
ax1.set_title('Sleep PRE')
ax2.set_title('LinearTrack')
ax3.set_title('Sleep POST')
ax2.yaxis.label.set_color('white')
ax2.tick_params(axis='y', colors='white')
ax3.yaxis.label.set_color('white')
ax3.tick_params(axis='y', colors='white')
'''
# Out:
# "\nax1.set_ylabel('EigVals PRE')\nax1.set_xlabel('#')\nax2.set_ylabel('EigVals LinearTrack')\nax2.set_xlabel('#')\nax3.set_ylabel('EigVals POST')\nax3.set_xlabel('#')\nax1.set_title('Sleep PRE')\nax2.set_title('LinearTrack')\nax3.set_title('Sleep POST')\nax2.yaxis.label.set_color('white')\nax2.tick_params(axis='y', colors='white')\nax3.yaxis.label.set_color('white')\nax3.tick_params(axis='y', colors='white')\n"

# %%
Gamma = []
TGamma = []
for ii in range(3):
    G = []
    TG = []
    for jj in range(int(N)):
        G.append(eigVecs[1][jj].T.dot(corrMatrices[ii]).dot(eigVecs[1][jj]))
        TG.append(ThetaEigVecs[1][jj].T.dot(ThetaCorrMatrices[ii]).dot(ThetaEigVecs[1][jj]))
    Gamma.append(np.array(G))
    TGamma.append(np.array(TG))

# %%
TW_limit,np.where(eigVals[2]>lMax[2]+TW_limit),np.where(ThetaEigVals[2]>TlMax[2]+TW_limit)
# Out:
# (0.049427927984923674,
#  (array([67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83,
#          84, 85, 86, 87, 88, 89, 90]),),
#  (array([66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82,
#          83, 84, 85, 86, 87, 88, 89, 90]),))

# %%
sigN = 70
f,(ax1,ax2,ax3) = pl.subplots(1,3,figsize=[30,10])
ax1.scatter(eigVals[1][sigN:],Gamma[0][sigN:],s=100)
ax1.scatter(ThetaEigVals[1][sigN:],TGamma[0][sigN:],c='r',s=100)
ax2.scatter(eigVals[1][sigN:],Gamma[2][sigN:],s=100)
ax2.scatter(ThetaEigVals[1][sigN:],TGamma[2][sigN:],c='r',s=100)
ax3.scatter(Gamma[0][sigN:],Gamma[2][sigN:],s=100)
ax3.scatter(TGamma[0][sigN:],TGamma[2][sigN:],c='r',s=100,alpha=0.7)
ax3.plot([1,1.5],[1,1.5],'k--', lw=1)
ax1.set_ylabel('Avg Reactivation PRE')
ax1.set_xlabel('Signal EigVals LinearTrack')
ax2.set_ylabel('Avg Reactivation POST')
ax2.set_xlabel('Signal EigVals LinearTrack')
ax3.set_ylabel('Avg Reactivation POST')
ax3.set_xlabel('Avg Reactivation PRE')
ax1.set_title('Sleep PRE')
ax2.set_title('Sleep POST')
ax3.set_title('PRE vs. POST')

# %%
reactivationStrengths  = np.array([Gamma[0][sigN:],Gamma[2][sigN:]])
TreactivationStrengths = np.array([TGamma[0][sigN:],TGamma[2][sigN:]])
pkl.dump(reactivationStrengths,open(WorkPath+'rat3906D4-100ms.cnt','wb'),pkl.HIGHEST_PROTOCOL)
pkl.dump(TreactivationStrengths,open(WorkPath+'rat3906D4-theta.cnt','wb'),pkl.HIGHEST_PROTOCOL)

# %%
Tidx = 1
Rz = []
threshold = []
for Midx in [0,2]:
    R0 = 0
    for ii in range(int(N)):
        for jj in range(int(N)):
            if ii != jj:
                R0 += Qs[Midx][ii]*corrMatrices[Tidx][ii,jj]*Qs[Midx][jj]
    #print R0
    Rz.append(R0)        
    threshold.append(R0.mean()+3.50*R0.std())
#    R0pPeaksTimes = X[scsig.argrelmax(R0p)]
#    R0pPeaksValues = R0p[scsig.argrelmax(R0p)]
# %matplotlib inline
f,(ax1,ax2) = pl.subplots(1,2,figsize=[20,5],sharex=True,sharey=True)
ax1.plot(Rz[0],label = 'PRE')
ax2.plot(Rz[1],'g',alpha=0.6,label = 'POST')
ax1.axhline(threshold[0],color='r')
ax2.axhline(threshold[1],color='r')
ax1.set_ylabel('R(t) PRE')
ax1.set_xlabel('time')
ax2.set_ylabel('R(t) POST')
ax2.set_xlabel('time')
pl.legend()

# %%
AAA = []
for ii in [0,1]:
    peakIdx = scsig.argrelmax(Rz[ii])
    sigPeaksIdx = np.where(Rz[ii][peakIdx]>threshold[ii])[0]
    sigPeaksVal = Rz[ii][sigPeaksIdx]
    A = sigPeaksIdx.size/1.0/Rz[ii].size
    B = Rz[ii][peakIdx].mean()
    Bs = Rz[ii][peakIdx].std()
    C = sigPeaksVal.mean()
    Cs = sigPeaksVal.std()
    AAA.append(np.array([A,B,Bs,C,Cs]))
print AAA[0]/AAA[1]
pkl.dump(AAA,open(WorkPath+'rat3906D4.rr','wb'),pkl.HIGHEST_PROTOCOL)
# Out:
# [ 1.85650532  0.80060097  0.49906261 -0.06874367  0.10658956]

# %%
Rz[1][peakIdx]
# Out:
# array([ 0.01270106,  0.01270106,  0.02646298, ...,  0.04034918,
#         0.02646298,  6.13095558])

# %%
#gammaAll_pre = np.array(np.array(Gamma[0][19:]),np.array(CGamma[0][18:]))
gamma_pre_All = np.append(Gamma[0][34:],CGamma[0][18:])
gamma_post_All = np.append(Gamma[2][34:],CGamma[2][18:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-01ebfc965b4f> in <module>()
#       1 #gammaAll_pre = np.array(np.array(Gamma[0][19:]),np.array(CGamma[0][18:]))
# ----> 2 gamma_pre_All = np.append(Gamma[0][34:],CGamma[0][18:])
#       3 gamma_post_All = np.append(Gamma[2][34:],CGamma[2][18:])
#
# NameError: name 'CGamma' is not defined

# %%
a,b = np.polyfit(Gamma[0][76:],Gamma[2][76:],1)
c,d = np.polyfit(CGamma[0][18:],CGamma[2][18:],1)
e,ff = np.polyfit(gamma_pre_All,gamma_post_All,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-539dad5f5903> in <module>()
# ----> 1 a,b = np.polyfit(Gamma[0][76:],Gamma[2][76:],1)
#       2 c,d = np.polyfit(CGamma[0][18:],CGamma[2][18:],1)
#       3 e,ff = np.polyfit(gamma_pre_All,gamma_post_All,1)
#
# /home/chenani/anaconda/lib/python2.7/site-packages/numpy/lib/polynomial.pyc in polyfit(x, y, deg, rcond, full, w, cov)
#     556         raise TypeError("expected 1D vector for x")
#     557     if x.size == 0:
# --> 558         raise TypeError("expected non-empty vector for x")
#     559     if y.ndim < 1 or y.ndim > 2:
#     560         raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x

# %%
f,(ax1,ax2,ax3) = pl.subplots(1,3,figsize=[20,5])
ax1.scatter(CeigVals[1][18:],CGamma[0][18:])
ax2.scatter(CeigVals[1][18:],CGamma[2][18:])
ax3.scatter(CGamma[0][18:],CGamma[2][18:])
ax3.plot([1,2],[1,2],'k--', lw=1)
ax1.set_ylabel('Avg Reactivation PRE')
ax1.set_xlabel('Signal EigVals LinearTrack')
ax2.set_ylabel('Avg Reactivation POST')
ax2.set_xlabel('Signal EigVals LinearTrack')
ax3.set_ylabel('Avg Reactivation POST')
ax3.set_xlabel('Avg Reactivation PRE')
ax1.set_title('Sleep PRE')
ax2.set_title('Sleep POST')
ax3.set_title('PRE vs. POST')
#pl.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4a93cc2a8e48> in <module>()
#       1 f,(ax1,ax2,ax3) = pl.subplots(1,3,figsize=[20,5])
# ----> 2 ax1.scatter(CeigVals[1][18:],CGamma[0][18:])
#       3 ax2.scatter(CeigVals[1][18:],CGamma[2][18:])
#       4 ax3.scatter(CGamma[0][18:],CGamma[2][18:])
#       5 ax3.plot([1,2],[1,2],'k--', lw=1)
#
# NameError: name 'CeigVals' is not defined

# %%
reactivationStrengths = np.array([CGamma[0][18:],CGamma[2][18:]])
pkl.dump(reactivationStrengths,open(WorkPath+'rat616.cnt','wb'),pkl.HIGHEST_PROTOCOL)

# %%
f,ax3 = pl.subplots(1,1,figsize=[7,7])
ax3.scatter(CGamma[0][18:],CGamma[2][18:],color='b',alpha = 0.9,label = 'Control')
ax3.scatter(Gamma[0][76:],Gamma[2][76:],color='r',alpha = 0.3,label='Lesioned')
ax3.plot([1,5],[a*1+b, a*5+b],'r--', lw=1)
ax3.plot([1,2],[c*1+d, c*2+d],'b--', lw=1)
ax3.plot([1,2],[e*1+ff, e*2+ff],'k--', lw=1)
ax3.plot([0,2],[0,2],'k--',lw=1)
ax3.set_ylim([0.9,2])
ax3.set_xlim([0.9,2])
ax3.set_ylabel('Avg Reactivation POST')
ax3.set_xlabel('Avg Reactivation PRE')
ax3.yaxis.label.set_color('white')
ax3.xaxis.label.set_color('white')
ax3.tick_params(axis='y', colors='white')
ax3.tick_params(axis='x', colors='white')
#pl.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-987c4af899f0> in <module>()
#       1 f,ax3 = pl.subplots(1,1,figsize=[7,7])
# ----> 2 ax3.scatter(CGamma[0][18:],CGamma[2][18:],color='b',alpha = 0.9,label = 'Control')
#       3 ax3.scatter(Gamma[0][76:],Gamma[2][76:],color='r',alpha = 0.3,label='Lesioned')
#       4 ax3.plot([1,5],[a*1+b, a*5+b],'r--', lw=1)
#       5 ax3.plot([1,2],[c*1+d, c*2+d],'b--', lw=1)
#
# NameError: name 'CGamma' is not defined

# %%
Ck = 0
for ii in range(21):
    for jj in range(21):
        Ck += CQs[0][ii]*CPs[1][20][ii,jj]*CQs[0][jj]
Ckk = 0
for ii in range(21):
    for jj in range(21):
        Ckk += CQs[2][ii]*CPs[1][20][ii,jj]*CQs[2][jj]

# %%
f,(ax1,ax2) = pl.subplots(1,2,figsize=[20,5],sharey=True)
ax1.plot(np.arange(CQs[0][1].size)/10,Ck,label='PRE')
ax2.plot(np.arange(CQs[2][1].size)/10,Ckk,'g',alpha=0.5,label='POST')
ax1.set_ylabel('R(t)')
ax1.set_xlabel('time')
ax2.set_xlabel('time')
pl.legend()

# %%
105-76
# Out:
# 29

# %%
fileNamesTrack = []
for ii,item in enumerate(CpllSpkTrns[1]):
    fileNamesTrack.append(CpllSpkTrns[1].tags[ii]['file'])
fileNamesSleep = []
for ii,item in enumerate(CpllSpkTrns[2]):
    fileNamesSleep.append(CpllSpkTrns[2].tags[ii]['file'])

# %%
idList = []
for ff in fileNames:
    for ii,item in enumerate(CpllSpkTrns[0]):
        if CpllSpkTrns[0].tags[ii]['file'] == ff:
            idList.append(CpllSpkTrns[0].id_list[ii])
print idList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-184-a68525d51283> in <module>()
#       1 idList = []
# ----> 2 for ff in fileNames:
#       3     for ii,item in enumerate(CpllSpkTrns[0]):
#       4         if CpllSpkTrns[0].tags[ii]['file'] == ff:
#       5             idList.append(CpllSpkTrns[0].id_list[ii])
#
# NameError: name 'fileNames' is not defined

# %%
fileNames = list(set(fileNamesSleep) & set(fileNamesTrack))

# %%
fileNames.sort()
len(fileNames)
# Out:
# 21

# %%
zugs = []
for train in CpllSpkTrns:
    ID = -1
    stList = signale.spikezugList(t_start=None, t_stop=None, dims=[2])
    idList = []
    for ff in fileNames:
        for ii,item in enumerate(train):
            if train.tags[ii]['file'] == ff:
                idList.append(train.id_list[ii])
    idList.sort()
    print idList
    for item in idList:
        ID+=1
        stList.__setitem__(ID,train[item])
        #stList.addTags(ID, file=item, dir=folderName)
    zugs.append(stList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-182-2ef78447b35b> in <module>()
#       4     stList = signale.spikezugList(t_start=None, t_stop=None, dims=[2])
#       5     idList = []
# ----> 6     for ff in fileNames:
#       7         for ii,item in enumerate(train):
#       8             if train.tags[ii]['file'] == ff:
#
# NameError: name 'fileNames' is not defined
