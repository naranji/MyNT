# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from scipy.misc import comb
import scipy as scp
import numpy as np
import matplotlib.pyplot as pl
import pickle as pkl
import sets
import random
import itertools
import os,sys,fnmatch
import timeit
import scipy.stats

# %%
def subsequence(sub,ref):
    '''
    A function to determine the number of specefic sequence repeated within a larger sequence.
    
    Parameters:
    sub:
    ref:
    
    
    Returns:
    idx : This an array containing the index of elements of sub in the ref! if idx is stricktly increasing the sequence sub
    is replayed whithin sequence ref!
    '''
    ref = np.array(ref)
    idx = np.array([])
    for ii in range(len(sub)):
        index = np.where(ref == sub[ii])[0]
        if index.size:
            idx = np.append(idx,index)
        else: 
            return [] , False
    idx = np.int0(idx)
    return idx, True

def median(arr):
    '''
    mY median... ;)
    '''
    arr = np.array(arr)
    if np.mod(arr.size,2) == 0 :
        return arr[arr.size / 2 - 1]
    else: 
        return arr[arr.size / 2 ]
    
def sequencer(arr,method = 'median'):
    '''
    This function sequences the given array(with possible repeated elements) into an array of distinct elements! Considering either 
    first or the midian position of repeated elements.
    '''
    arr = np.array(arr)
    idx_seq = np.array([])
    if method == 'median':
        for item in set(arr):
            idx_seq = np.append(idx_seq,median(np.where(arr == item)[0]))
        idx_seq.sort()
    if method == 'first':
        for item in set(arr):
            idx_seq = np.append(idx_seq,np.where(arr == item)[0][0])
        idx_seq.sort()

    return arr[np.int0(idx_seq)]

def duplicate_indicator(arr_group,weights=np.array([]),rptIndex = False):
    '''
    Finds and counts the duplicates! This Function makes a frequency distribution the number of
    arrays within a goup of arrays.
    
    Parameters:
    -----------
    arr_group: The one that you want to count
    weights: an array containig the wights(results of a previous counting of etc.). 
    If non empty the distribution will be weighted 
             with respect to this array!
    Returns:
    -----------
    arr_set: Set of distinct arrays in arr_group
    arr_weights: repitition counts of elements in arr_set.
    '''
    
    arr_cp = np.copy(arr_group)   
    for ii in range(len(arr_group)):
        for jj in range(len(arr_group)):
            if np.array_equal(arr_cp[jj], arr_cp[ii]) and ii != jj:
                arr_cp[jj] = np.array([-1])
    arr_set = []
    for item in arr_cp:
        if item.sum() > 0:
            arr_set.append(item)
    arr_set = np.array(arr_set)
    ### Counting number of repititions
    
    if rptIndex:
        rptIndex = []
        arr_weights = np.zeros(len(arr_set))
        for ii in range(len(arr_set)):
            rpt_idx = []
            for jj in range(len(arr_group)):
                if np.array_equal(arr_group[jj],arr_set[ii]):
                    if weights.size:
                        arr_weights[ii] += weights[jj]
                        rpt_idx.append(jj)
                    else:
                        arr_weights[ii] += 1
                        rpt_idx.append(jj)
            rptIndex.append(np.array(rpt_idx))
        return arr_set,arr_weights,rptIndex
    else:
        arr_weights = np.zeros(len(arr_set))
        for ii in range(len(arr_set)):
            for jj in range(len(arr_group)):
                if np.array_equal(arr_group[jj],arr_set[ii]):
                    if weights.size:
                        arr_weights[ii] += weights[jj]
                    else:
                        arr_weights[ii] += 1
        return arr_set,arr_weights
                    
    

def next_permutation(arr):
    '''
    
        Computes the next lexicographical permutation of the specified list in place,
     returning whether a next permutation existed. (Returns False when the argument
     is already the last possible permutation.)
    
    
         Example:
            arr = [0, 1, 0]
            next_permutation(arr)  (returns True)
            arr has been modified to be [1, 0, 0]
    Reference:
    -----------
    Nayuki Minase, 2014. Public domain.
    http://nayuki.eigenstate.org/page/next-lexicographical-permutation-algorithm
            '''
    
    i = len(arr) - 1
    while i > 0 and arr[i - 1] >= arr[i]:
        i -= 1
    if i <= 0:
        return False
    
    # Find successor to pivot
    j = len(arr) - 1
    while arr[j] <= arr[i - 1]:
        j -= 1
    arr[i - 1], arr[j] = arr[j], arr[i - 1]
    
    # Reverse suffix
    arr[i : ] = arr[len(arr) - 1 : i - 1 : -1]
    return True

def number_of_permutations(arr):
    Cnk = [] #keep the combinations!
    s = 0    # sum of repitiotions of elements in arr!
    arrcp = np.array(arr).copy()
    arrcp.sort()
    for item in set(arrcp):
        reps = np.where(arrcp == item)[0].size
        Cnk.append(comb(arrcp.size - s,reps,True))
        s += reps
    return np.prod(np.array(Cnk))
def all_permutations(arr):
    '''
    produces all possible permutations of a given array using lexographical ordering.
    Sequence the arrays and returns the weights of all possible sequences!
    This version is fast but memory consuming, better for the short arrays!
    written by A. Chenani Sep. 2014
    '''
    sqStack = []
    weightsStack = []
    for item in arr:
        item.sort()
        arr_seqz = [sequencer(item)]
        #####Cunstructing sequence set
        #start =  timeit.default_timer()
        
        arr_seqz_set = np.array([])
        sample_seq = arr_seqz[0].copy()
        sample_seq.sort()
        arr_seqz_set = np.append(arr_seqz_set,sample_seq)
        while next_permutation(sample_seq):
            arr_seqz_set = np.append(arr_seqz_set,sample_seq)
        arr_seqz_set = arr_seqz_set.reshape(np.math.factorial(sample_seq.size),arr_seqz[0].size)
        
        #stop = timeit.default_timer()
        #print 'part one --> %f' %(stop - start)
        
        
        #####creating MUA permutation list!
        #start =  timeit.default_timer()
        
        while next_permutation(item):
            arr_seqz.append(sequencer(item))
        arr_seqz = np.array(arr_seqz) #This contains all sequences coming from permutations of an specific MUA!
       
        #stop = timeit.default_timer()
        #print 'part two --> %f' %(stop - start)
        
        #####Calculating the wights of all possible sequences
        #start =  timeit.default_timer()
        weights = []
        for item in arr_seqz_set:
            selection = arr_seqz[np.where(arr_seqz[:,0]==item[0])[0]]
            for ii in range(1,arr_seqz_set.shape[1]):
                selection = selection[np.where(selection[:,ii]==item[ii])[0]]
            weights.append(selection.size/float(arr_seqz.size))
        weightsStack.append(np.array(weights))
        sqStack.append(arr_seqz_set)
        
        #stop = timeit.default_timer()
        #print 'part three --> %f' %(stop - start)
    return sqStack,weightsStack
def All_permutations(arr):
    '''
    produces all possible permutations of a given array using lexographical ordering.
    Sequence the arrays and returns the weights of all possible sequences!
    This version is not using that much memory but its slow, better for long arrays.
    written by A. Chenani Sep. 2014
    '''
    sqStack = []
    weightsStack = []
    for item in arr:
        item.sort()
        #####Cunstructing sequence set
        arr_seqz_set = np.array([])
        sample_seq = sequencer(item)
        sample_seq.sort()
        arr_seqz_set = np.append(arr_seqz_set,sample_seq)
        while next_permutation(sample_seq):
            arr_seqz_set = np.append(arr_seqz_set,sample_seq)
        arr_seqz_set = arr_seqz_set.reshape(np.math.factorial(sample_seq.size),sample_seq.size)
        
        
        
        
        #####creating MUA permutation list!
        start =  timeit.default_timer()
        lexRank = [0]
        while next_permutation(item):
            selection = np.arange(arr_seqz_set.size)
            for ii in range(arr_seqz_set[0].size -1 ):
                selection = np.intersect1d(selection,np.where(arr_seqz_set[:,ii]==sequencer(item)[ii])[0])
            lexRank.append(selection[0])
        lexRank = np.array(lexRank)
        stop = timeit.default_timer()
        print 'part two --> %f' %(stop - start)
        #####Calculating the wights of all possible sequences
        weights = []
        for ii,item in enumerate(arr_seqz_set):
            weights.append(np.where(lexRank == ii)[0].size /float(lexRank.size))
        weightsStack.append(np.array(weights))
        sqStack.append(arr_seqz_set)
    return sqStack,weightsStack

def locate(pattern, root=os.curdir):
    '''Locate all files matching supplied filename pattern in and below
        supplied root directory.
    '''
    for path, dirs, files in os.walk(os.path.abspath(root)):
        for filename in fnmatch.filter(files, pattern):
            yield [path,filename]

# %%
cd /media/chenani/Data/ephysdata/Rats/MECLesion/Rat616Control/2013-06-02_07-42-38/sleep2/
# Out:
# /media/chenani/Data/ephysdata/Rats/MECLesion/Rat616Control/2013-06-02_07-42-38/sleep2

# %%
probFile = './probs_pl/seqz-length4.prob'
mua = pkl.load(open('place_cells.mua','rb'))
mua = np.array(mua)
### Filtering the place cells from recorded sequences
plSeqz = []
plSeqz_idx = []
for ii,item in enumerate(mua):
    sqz = sequencer(item)
    if sqz.size > 1:
        plSeqz.append(sqz)
        plSeqz_idx.append(ii)
    else:
        plSeqz.append(np.arange(200,210))
        plSeqz_idx.append(-1)
plSeqz_idx = np.array(plSeqz_idx)
plSeqz = np.array(plSeqz)

# %%
set_len = []
for item in plSeqz:
    set_len.append(len(set(item)))
set_len = np.int0(set_len)
pl.hist(set_len,20);

# %%
dataIndex = np.where(set_len ==4)[0]
mua = mua[dataIndex]
plSeqz = plSeqz[dataIndex]

# %%
probs_seqz,probs = pkl.load(open(probFile,'rb'))

# %%
mua_set,muaW8tz,rpt = duplicate_indicator(mua,rptIndex=True)
seqz_set,seqzW8tz = duplicate_indicator(plSeqz)

# %%
equalMUAIndex = []
for ii,item in enumerate(mua_set):
    #print item
    #print '---'
    eq_mua_idx = []
    for jj in range(ii+1,len(mua_set)):
        if np.array_equal(np.histogram(item,np.unique(item).size)[0],np.histogram(mua_set[jj],np.unique(item).size)[0]):
            if np.array_equal(np.unique(item),np.unique(mua_set[jj])):
                eq_mua_idx.append(jj)
                #print jj
    equalMUAIndex.append(np.array(eq_mua_idx))
    #print '*******'

# %%
sigVec = []
sigSeqz = []
for ii in range(len(mua_set)):
    sq =  sequencer(mua_set[ii])
    n = sq.size
    #print muaW8tz[ii]
    for jj in range(np.math.factorial(n)):
        if np.array_equal(sq,np.array(probs_seqz)[rpt[ii]][0][jj]):
            if equalMUAIndex[ii].size:
                equivalentsSummed = np.sum(muaW8tz[equalMUAIndex[ii]])
                #print equivalentsSummed
                #print np.array(probs)[rpt[ii]][0][jj]
                n = muaW8tz[ii]+equivalentsSummed
                pval = scipy.stats.binom_test(muaW8tz[ii],n,np.array(probs)[rpt[ii]][0][jj])
                if pval < 0.05:
                    print mua_set[ii]
                    print sq
                    print 'with %d (%d,%d) repititions'%(n,muaW8tz[ii],equivalentsSummed)
                    print 'Significant with p-value %f in Binomial test' %pval
                    print np.array(probs_seqz)[rpt[ii]][0]
                    print np.array(probs)[rpt[ii]][0]
                    print '###########################################################################'
                sigVec.append(pval)
                sigSeqz.append(sq)
            else:
                #print np.array(probs)[rpt[ii]][0][jj]
                pval = scipy.stats.binom_test(muaW8tz[ii],muaW8tz[ii],np.array(probs)[rpt[ii]][0][jj])
                if pval < 0.05:
                    print mua_set[ii]
                    print sq
                    print 'with %d repititions'%muaW8tz[ii]
                    print 'Significant with p-value %f in Binomial test' %pval
                    print np.array(probs_seqz)[rpt[ii]][0]
                    print np.array(probs)[rpt[ii]][0]
                    print '###########################################################################'
                sigVec.append(pval)
                sigSeqz.append(sq)
    #print '****************************************'
sigVec = np.array(sigVec)
# Out:
# [12 12  9 12 11  0]
# [12  9 11  0]
# with 1 repititions
# Significant with p-value 0.033333 in Binomial test
# [[  0.   9.  11.  12.]
#  [  0.   9.  12.  11.]
#  [  0.  11.   9.  12.]
#  [  0.  11.  12.   9.]
#  [  0.  12.   9.  11.]
#  [  0.  12.  11.   9.]
#  [  9.   0.  11.  12.]
#  [  9.   0.  12.  11.]
#  [  9.  11.   0.  12.]
#  [  9.  11.  12.   0.]
#  [  9.  12.   0.  11.]
#  [  9.  12.  11.   0.]
#  [ 11.   0.   9.  12.]
#  [ 11.   0.  12.   9.]
#  [ 11.   9.   0.  12.]
#  [ 11.   9.  12.   0.]
#  [ 11.  12.   0.   9.]
#  [ 11.  12.   9.   0.]
#  [ 12.   0.   9.  11.]
#  [ 12.   0.  11.   9.]
#  [ 12.   9.   0.  11.]
#  [ 12.   9.  11.   0.]
#  [ 12.  11.   0.   9.]
#  [ 12.  11.   9.   0.]]
# [ 0.03333333  0.05        0.03333333  0.05        0.05        0.05
#   0.03333333  0.05        0.03333333  0.05        0.05        0.05
#   0.03333333  0.05        0.03333333  0.05        0.05        0.05
#   0.03333333  0.03333333  0.03333333  0.03333333  0.03333333  0.03333333]
# ###########################################################################
# [ 1  1  1 12 12  0  0 13 13]
# [ 1 12  0 13]
# with 2 (1,1) repititions
# Significant with p-value 0.027585 in Binomial test
# [[  0.   1.  12.  13.]
#  [  0.   1.  13.  12.]
#  [  0.  12.   1.  13.]
#  [  0.  12.  13.   1.]
#  [  0.  13.   1.  12.]
#  [  0.  13.  12.   1.]
#  [  1.   0.  12.  13.]
#  [  1.   0.  13.  12.]
#  [  1.  12.   0.  13.]
#  [  1.  12.  13.   0.]
#  [  1.  13.   0.  12.]
#  [  1.  13.  12.   0.]
#  [ 12.   0.   1.  13.]
#  [ 12.   0.  13.   1.]
#  [ 12.   1.   0.  13.]
#  [ 12.   1.  13.   0.]
#  [ 12.  13.   0.   1.]
#  [ 12.  13.   1.   0.]
#  [ 13.   0.   1.  12.]
#  [ 13.   0.  12.   1.]
#  [ 13.   1.   0.  12.]
#  [ 13.   1.  12.   0.]
#  [ 13.  12.   0.   1.]
#  [ 13.  12.   1.   0.]]
# [ 0.0297619   0.0297619   0.04880952  0.07420635  0.04880952  0.07420635
#   0.01388889  0.01388889  0.01388889  0.01388889  0.01388889  0.01388889
#   0.04880952  0.07420635  0.0297619   0.0297619   0.07420635  0.04880952
#   0.04880952  0.07420635  0.0297619   0.0297619   0.07420635  0.04880952]
# ###########################################################################
# [ 9  9  9  6  6  6 10 10  1]
# [ 9  6 10  1]
# with 1 repititions
# Significant with p-value 0.030159 in Binomial test
# [[  1.   6.   9.  10.]
#  [  1.   6.  10.   9.]
#  [  1.   9.   6.  10.]
#  [  1.   9.  10.   6.]
#  [  1.  10.   6.   9.]
#  [  1.  10.   9.   6.]
#  [  6.   1.   9.  10.]
#  [  6.   1.  10.   9.]
#  [  6.   9.   1.  10.]
#  [  6.   9.  10.   1.]
#  [  6.  10.   1.   9.]
#  [  6.  10.   9.   1.]
#  [  9.   1.   6.  10.]
#  [  9.   1.  10.   6.]
#  [  9.   6.   1.  10.]
#  [  9.   6.  10.   1.]
#  [  9.  10.   1.   6.]
#  [  9.  10.   6.   1.]
#  [ 10.   1.   6.   9.]
#  [ 10.   1.   9.   6.]
#  [ 10.   6.   1.   9.]
#  [ 10.   6.   9.   1.]
#  [ 10.   9.   1.   6.]
#  [ 10.   9.   6.   1.]]
# [ 0.025       0.03452381  0.025       0.03452381  0.05555556  0.05555556
#   0.01547619  0.02103175  0.01507937  0.03015873  0.02896825  0.04404762
#   0.01547619  0.02103175  0.01507937  0.03015873  0.02896825  0.04404762
#   0.07063492  0.07063492  0.06309524  0.09642857  0.06309524  0.09642857]
# ###########################################################################
# [ 9 13 12  0 13 13]
# [ 9 12  0 13]
# with 1 repititions
# Significant with p-value 0.033333 in Binomial test
# [[  0.   9.  12.  13.]
#  [  0.   9.  13.  12.]
#  [  0.  12.   9.  13.]
#  [  0.  12.  13.   9.]
#  [  0.  13.   9.  12.]
#  [  0.  13.  12.   9.]
#  [  9.   0.  12.  13.]
#  [  9.   0.  13.  12.]
#  [  9.  12.   0.  13.]
#  [  9.  12.  13.   0.]
#  [  9.  13.   0.  12.]
#  [  9.  13.  12.   0.]
#  [ 12.   0.   9.  13.]
#  [ 12.   0.  13.   9.]
#  [ 12.   9.   0.  13.]
#  [ 12.   9.  13.   0.]
#  [ 12.  13.   0.   9.]
#  [ 12.  13.   9.   0.]
#  [ 13.   0.   9.  12.]
#  [ 13.   0.  12.   9.]
#  [ 13.   9.   0.  12.]
#  [ 13.   9.  12.   0.]
#  [ 13.  12.   0.   9.]
#  [ 13.  12.   9.   0.]]
# [ 0.03333333  0.05        0.03333333  0.05        0.05        0.05
#   0.03333333  0.05        0.03333333  0.05        0.05        0.05
#   0.03333333  0.05        0.03333333  0.05        0.05        0.05
#   0.03333333  0.03333333  0.03333333  0.03333333  0.03333333  0.03333333]
# ###########################################################################
# [ 0  0  0  1 10 10  9  9]
# [ 0  1 10  9]
# with 1 repititions
# Significant with p-value 0.010714 in Binomial test
# [[  0.   1.   9.  10.]
#  [  0.   1.  10.   9.]
#  [  0.   9.   1.  10.]
#  [  0.   9.  10.   1.]
#  [  0.  10.   1.   9.]
#  [  0.  10.   9.   1.]
#  [  1.   0.   9.  10.]
#  [  1.   0.  10.   9.]
#  [  1.   9.   0.  10.]
#  [  1.   9.  10.   0.]
#  [  1.  10.   0.   9.]
#  [  1.  10.   9.   0.]
#  [  9.   0.   1.  10.]
#  [  9.   0.  10.   1.]
#  [  9.   1.   0.  10.]
#  [  9.   1.  10.   0.]
#  [  9.  10.   0.   1.]
#  [  9.  10.   1.   0.]
#  [ 10.   0.   1.   9.]
#  [ 10.   0.   9.   1.]
#  [ 10.   1.   0.   9.]
#  [ 10.   1.   9.   0.]
#  [ 10.   9.   0.   1.]
#  [ 10.   9.   1.   0.]]
# [ 0.01071429  0.01071429  0.01428571  0.02857143  0.01428571  0.02857143
#   0.01785714  0.01785714  0.02857143  0.04285714  0.02857143  0.04285714
#   0.03095238  0.06190476  0.03571429  0.05238095  0.10357143  0.07261905
#   0.03095238  0.06190476  0.03571429  0.05238095  0.10357143  0.07261905]
# ###########################################################################
# [ 6  9  9 10  1  1  1 10]
# [ 6  9 10  1]
# with 1 repititions
# Significant with p-value 0.042857 in Binomial test
# [[  1.   6.   9.  10.]
#  [  1.   6.  10.   9.]
#  [  1.   9.   6.  10.]
#  [  1.   9.  10.   6.]
#  [  1.  10.   6.   9.]
#  [  1.  10.   9.   6.]
#  [  6.   1.   9.  10.]
#  [  6.   1.  10.   9.]
#  [  6.   9.   1.  10.]
#  [  6.   9.  10.   1.]
#  [  6.  10.   1.   9.]
#  [  6.  10.   9.   1.]
#  [  9.   1.   6.  10.]
#  [  9.   1.  10.   6.]
#  [  9.   6.   1.  10.]
#  [  9.   6.  10.   1.]
#  [  9.  10.   1.   6.]
#  [  9.  10.   6.   1.]
#  [ 10.   1.   6.   9.]
#  [ 10.   1.   9.   6.]
#  [ 10.   6.   1.   9.]
#  [ 10.   6.   9.   1.]
#  [ 10.   9.   1.   6.]
#  [ 10.   9.   6.   1.]]
# [ 0.01071429  0.01071429  0.01428571  0.02857143  0.01428571  0.02857143
#   0.01785714  0.01785714  0.02857143  0.04285714  0.02857143  0.04285714
#   0.03095238  0.06190476  0.03571429  0.05238095  0.10357143  0.07261905
#   0.03095238  0.06190476  0.03571429  0.05238095  0.10357143  0.07261905]
# ###########################################################################
# [12  0 20 20 13]
# [12  0 20 13]
# with 1 repititions
# Significant with p-value 0.033333 in Binomial test
# [[  0.  12.  13.  20.]
#  [  0.  12.  20.  13.]
#  [  0.  13.  12.  20.]
#  [  0.  13.  20.  12.]
#  [  0.  20.  12.  13.]
#  [  0.  20.  13.  12.]
#  [ 12.   0.  13.  20.]
#  [ 12.   0.  20.  13.]
#  [ 12.  13.   0.  20.]
#  [ 12.  13.  20.   0.]
#  [ 12.  20.   0.  13.]
#  [ 12.  20.  13.   0.]
#  [ 13.   0.  12.  20.]
#  [ 13.   0.  20.  12.]
#  [ 13.  12.   0.  20.]
#  [ 13.  12.  20.   0.]
#  [ 13.  20.   0.  12.]
#  [ 13.  20.  12.   0.]
#  [ 20.   0.  12.  13.]
#  [ 20.   0.  13.  12.]
#  [ 20.  12.   0.  13.]
#  [ 20.  12.  13.   0.]
#  [ 20.  13.   0.  12.]
#  [ 20.  13.  12.   0.]]
# [ 0.01666667  0.03333333  0.01666667  0.03333333  0.05        0.05
#   0.01666667  0.03333333  0.01666667  0.03333333  0.05        0.05
#   0.01666667  0.03333333  0.01666667  0.03333333  0.05        0.05
#   0.06666667  0.06666667  0.06666667  0.06666667  0.06666667  0.06666667]
# ###########################################################################
# [ 0 20 13 13 18]
# [ 0 20 13 18]
# with 1 repititions
# Significant with p-value 0.033333 in Binomial test
# [[  0.  13.  18.  20.]
#  [  0.  13.  20.  18.]
#  [  0.  18.  13.  20.]
#  [  0.  18.  20.  13.]
#  [  0.  20.  13.  18.]
#  [  0.  20.  18.  13.]
#  [ 13.   0.  18.  20.]
#  [ 13.   0.  20.  18.]
#  [ 13.  18.   0.  20.]
#  [ 13.  18.  20.   0.]
#  [ 13.  20.   0.  18.]
#  [ 13.  20.  18.   0.]
#  [ 18.   0.  13.  20.]
#  [ 18.   0.  20.  13.]
#  [ 18.  13.   0.  20.]
#  [ 18.  13.  20.   0.]
#  [ 18.  20.   0.  13.]
#  [ 18.  20.  13.   0.]
#  [ 20.   0.  13.  18.]
#  [ 20.   0.  18.  13.]
#  [ 20.  13.   0.  18.]
#  [ 20.  13.  18.   0.]
#  [ 20.  18.   0.  13.]
#  [ 20.  18.  13.   0.]]
# [ 0.05        0.05        0.03333333  0.01666667  0.03333333  0.01666667
#   0.06666667  0.06666667  0.06666667  0.06666667  0.06666667  0.06666667
#   0.03333333  0.01666667  0.05        0.05        0.01666667  0.03333333
#   0.03333333  0.01666667  0.05        0.05        0.01666667  0.03333333]
# ###########################################################################
# [12  1 12 12 12  0  0 12  6  6  6]
# [ 1 12  0  6]
# with 1 repititions
# Significant with p-value 0.035390 in Binomial test
# [[  0.   1.   6.  12.]
#  [  0.   1.  12.   6.]
#  [  0.   6.   1.  12.]
#  [  0.   6.  12.   1.]
#  [  0.  12.   1.   6.]
#  [  0.  12.   6.   1.]
#  [  1.   0.   6.  12.]
#  [  1.   0.  12.   6.]
#  [  1.   6.   0.  12.]
#  [  1.   6.  12.   0.]
#  [  1.  12.   0.   6.]
#  [  1.  12.   6.   0.]
#  [  6.   0.   1.  12.]
#  [  6.   0.  12.   1.]
#  [  6.   1.   0.  12.]
#  [  6.   1.  12.   0.]
#  [  6.  12.   0.   1.]
#  [  6.  12.   1.   0.]
#  [ 12.   0.   1.   6.]
#  [ 12.   0.   6.   1.]
#  [ 12.   1.   0.   6.]
#  [ 12.   1.   6.   0.]
#  [ 12.   6.   0.   1.]
#  [ 12.   6.   1.   0.]]
# [ 0.06544012  0.07864358  0.05616883  0.10465368  0.06601732  0.10281385
#   0.0523088   0.06204906  0.03268398  0.02813853  0.03538961  0.0262987
#   0.02593795  0.04794372  0.01962482  0.01731602  0.03318903  0.01659452
#   0.02323232  0.03636364  0.01691919  0.01287879  0.02626263  0.01313131]
# ###########################################################################
# [ 0  0 13 12  1  0 12  0 12]
# [ 0 13  1 12]
# with 1 repititions
# Significant with p-value 0.036905 in Binomial test
# [[  0.   1.  12.  13.]
#  [  0.   1.  13.  12.]
#  [  0.  12.   1.  13.]
#  [  0.  12.  13.   1.]
#  [  0.  13.   1.  12.]
#  [  0.  13.  12.   1.]
#  [  1.   0.  12.  13.]
#  [  1.   0.  13.  12.]
#  [  1.  12.   0.  13.]
#  [  1.  12.  13.   0.]
#  [  1.  13.   0.  12.]
#  [  1.  13.  12.   0.]
#  [ 12.   0.   1.  13.]
#  [ 12.   0.  13.   1.]
#  [ 12.   1.   0.  13.]
#  [ 12.   1.  13.   0.]
#  [ 12.  13.   0.   1.]
#  [ 12.  13.   1.   0.]
#  [ 13.   0.   1.  12.]
#  [ 13.   0.  12.   1.]
#  [ 13.   1.   0.  12.]
#  [ 13.   1.  12.   0.]
#  [ 13.  12.   0.   1.]
#  [ 13.  12.   1.   0.]]
# [ 0.05714286  0.03690476  0.06071429  0.06071429  0.03690476  0.05714286
#   0.07142857  0.04761905  0.05        0.02142857  0.04047619  0.025
#   0.0452381   0.0452381   0.03095238  0.01309524  0.03095238  0.01309524
#   0.04761905  0.07142857  0.04047619  0.025       0.05        0.02142857]
# ###########################################################################
# [ 1 11 12  0  0  0]
# [ 1 11 12  0]
# with 1 repititions
# Significant with p-value 0.033333 in Binomial test
# [[  0.   1.  11.  12.]
#  [  0.   1.  12.  11.]
#  [  0.  11.   1.  12.]
#  [  0.  11.  12.   1.]
#  [  0.  12.   1.  11.]
#  [  0.  12.  11.   1.]
#  [  1.   0.  11.  12.]
#  [  1.   0.  12.  11.]
#  [  1.  11.   0.  12.]
#  [  1.  11.  12.   0.]
#  [  1.  12.   0.  11.]
#  [  1.  12.  11.   0.]
#  [ 11.   0.   1.  12.]
#  [ 11.   0.  12.   1.]
#  [ 11.   1.   0.  12.]
#  [ 11.   1.  12.   0.]
#  [ 11.  12.   0.   1.]
#  [ 11.  12.   1.   0.]
#  [ 12.   0.   1.  11.]
#  [ 12.   0.  11.   1.]
#  [ 12.   1.   0.  11.]
#  [ 12.   1.  11.   0.]
#  [ 12.  11.   0.   1.]
#  [ 12.  11.   1.   0.]]
# [ 0.03333333  0.03333333  0.03333333  0.03333333  0.03333333  0.03333333
#   0.05        0.05        0.05        0.03333333  0.05        0.03333333
#   0.05        0.05        0.05        0.03333333  0.05        0.03333333
#   0.05        0.05        0.05        0.03333333  0.05        0.03333333]
# ###########################################################################
# [13  0 12 12 13  1  1 13  0]
# [ 0 12 13  1]
# with 1 repititions
# Significant with p-value 0.048810 in Binomial test
# [[  0.   1.  12.  13.]
#  [  0.   1.  13.  12.]
#  [  0.  12.   1.  13.]
#  [  0.  12.  13.   1.]
#  [  0.  13.   1.  12.]
#  [  0.  13.  12.   1.]
#  [  1.   0.  12.  13.]
#  [  1.   0.  13.  12.]
#  [  1.  12.   0.  13.]
#  [  1.  12.  13.   0.]
#  [  1.  13.   0.  12.]
#  [  1.  13.  12.   0.]
#  [ 12.   0.   1.  13.]
#  [ 12.   0.  13.   1.]
#  [ 12.   1.   0.  13.]
#  [ 12.   1.  13.   0.]
#  [ 12.  13.   0.   1.]
#  [ 12.  13.   1.   0.]
#  [ 13.   0.   1.  12.]
#  [ 13.   0.  12.   1.]
#  [ 13.   1.   0.  12.]
#  [ 13.   1.  12.   0.]
#  [ 13.  12.   0.   1.]
#  [ 13.  12.   1.   0.]]
# [ 0.07420635  0.04880952  0.07420635  0.04880952  0.0297619   0.0297619
#   0.07420635  0.04880952  0.07420635  0.04880952  0.0297619   0.0297619
#   0.07420635  0.04880952  0.07420635  0.04880952  0.0297619   0.0297619
#   0.01388889  0.01388889  0.01388889  0.01388889  0.01388889  0.01388889]
# ###########################################################################
# [20 12  9  6  9]
# [20 12  9  6]
# with 1 repititions
# Significant with p-value 0.033333 in Binomial test
# [[  6.   9.  12.  20.]
#  [  6.   9.  20.  12.]
#  [  6.  12.   9.  20.]
#  [  6.  12.  20.   9.]
#  [  6.  20.   9.  12.]
#  [  6.  20.  12.   9.]
#  [  9.   6.  12.  20.]
#  [  9.   6.  20.  12.]
#  [  9.  12.   6.  20.]
#  [  9.  12.  20.   6.]
#  [  9.  20.   6.  12.]
#  [  9.  20.  12.   6.]
#  [ 12.   6.   9.  20.]
#  [ 12.   6.  20.   9.]
#  [ 12.   9.   6.  20.]
#  [ 12.   9.  20.   6.]
#  [ 12.  20.   6.   9.]
#  [ 12.  20.   9.   6.]
#  [ 20.   6.   9.  12.]
#  [ 20.   6.  12.   9.]
#  [ 20.   9.   6.  12.]
#  [ 20.   9.  12.   6.]
#  [ 20.  12.   6.   9.]
#  [ 20.  12.   9.   6.]]
# [ 0.05        0.05        0.03333333  0.01666667  0.03333333  0.01666667
#   0.06666667  0.06666667  0.06666667  0.06666667  0.06666667  0.06666667
#   0.03333333  0.01666667  0.05        0.05        0.01666667  0.03333333
#   0.03333333  0.01666667  0.05        0.05        0.01666667  0.03333333]
# ###########################################################################
# [12 12 11 13 13  0  0]
# [12 11 13  0]
# with 1 repititions
# Significant with p-value 0.028571 in Binomial test
# [[  0.  11.  12.  13.]
#  [  0.  11.  13.  12.]
#  [  0.  12.  11.  13.]
#  [  0.  12.  13.  11.]
#  [  0.  13.  11.  12.]
#  [  0.  13.  12.  11.]
#  [ 11.   0.  12.  13.]
#  [ 11.   0.  13.  12.]
#  [ 11.  12.   0.  13.]
#  [ 11.  12.  13.   0.]
#  [ 11.  13.   0.  12.]
#  [ 11.  13.  12.   0.]
#  [ 12.   0.  11.  13.]
#  [ 12.   0.  13.  11.]
#  [ 12.  11.   0.  13.]
#  [ 12.  11.  13.   0.]
#  [ 12.  13.   0.  11.]
#  [ 12.  13.  11.   0.]
#  [ 13.   0.  11.  12.]
#  [ 13.   0.  12.  11.]
#  [ 13.  11.   0.  12.]
#  [ 13.  11.  12.   0.]
#  [ 13.  12.   0.  11.]
#  [ 13.  12.  11.   0.]]
# [ 0.02857143  0.02857143  0.03809524  0.07619048  0.03809524  0.07619048
#   0.02380952  0.02380952  0.02380952  0.02380952  0.02380952  0.02380952
#   0.03809524  0.07619048  0.02857143  0.02857143  0.07619048  0.03809524
#   0.03809524  0.07619048  0.02857143  0.02857143  0.07619048  0.03809524]
# ###########################################################################
# [ 6 10 10  9  1  1]
# [ 6 10  9  1]
# with 1 repititions
# Significant with p-value 0.022222 in Binomial test
# [[  1.   6.   9.  10.]
#  [  1.   6.  10.   9.]
#  [  1.   9.   6.  10.]
#  [  1.   9.  10.   6.]
#  [  1.  10.   6.   9.]
#  [  1.  10.   9.   6.]
#  [  6.   1.   9.  10.]
#  [  6.   1.  10.   9.]
#  [  6.   9.   1.  10.]
#  [  6.   9.  10.   1.]
#  [  6.  10.   1.   9.]
#  [  6.  10.   9.   1.]
#  [  9.   1.   6.  10.]
#  [  9.   1.  10.   6.]
#  [  9.   6.   1.  10.]
#  [  9.   6.  10.   1.]
#  [  9.  10.   1.   6.]
#  [  9.  10.   6.   1.]
#  [ 10.   1.   6.   9.]
#  [ 10.   1.   9.   6.]
#  [ 10.   6.   1.   9.]
#  [ 10.   6.   9.   1.]
#  [ 10.   9.   1.   6.]
#  [ 10.   9.   6.   1.]]
# [ 0.02777778  0.05555556  0.02777778  0.05555556  0.08333333  0.08333333
#   0.02222222  0.04444444  0.01666667  0.01666667  0.04444444  0.02222222
#   0.02222222  0.04444444  0.01666667  0.01666667  0.04444444  0.02222222
#   0.08333333  0.08333333  0.05555556  0.02777778  0.05555556  0.02777778]
# ###########################################################################
# [13 11 11 11 13 12  0 13]
# [11 13 12  0]
# with 1 repititions
# Significant with p-value 0.042857 in Binomial test
# [[  0.  11.  12.  13.]
#  [  0.  11.  13.  12.]
#  [  0.  12.  11.  13.]
#  [  0.  12.  13.  11.]
#  [  0.  13.  11.  12.]
#  [  0.  13.  12.  11.]
#  [ 11.   0.  12.  13.]
#  [ 11.   0.  13.  12.]
#  [ 11.  12.   0.  13.]
#  [ 11.  12.  13.   0.]
#  [ 11.  13.   0.  12.]
#  [ 11.  13.  12.   0.]
#  [ 12.   0.  11.  13.]
#  [ 12.   0.  13.  11.]
#  [ 12.  11.   0.  13.]
#  [ 12.  11.  13.   0.]
#  [ 12.  13.   0.  11.]
#  [ 12.  13.  11.   0.]
#  [ 13.   0.  11.  12.]
#  [ 13.   0.  12.  11.]
#  [ 13.  11.   0.  12.]
#  [ 13.  11.  12.   0.]
#  [ 13.  12.   0.  11.]
#  [ 13.  12.  11.   0.]]
# [ 0.03928571  0.06071429  0.04285714  0.04285714  0.06071429  0.03928571
#   0.025       0.03928571  0.025       0.03928571  0.04285714  0.04285714
#   0.04285714  0.04285714  0.03928571  0.06071429  0.03928571  0.06071429
#   0.03928571  0.025       0.04285714  0.04285714  0.025       0.03928571]
# ###########################################################################
# [12 12  0 12 11 11 13 13 13]
# [12  0 11 13]
# with 1 repititions
# Significant with p-value 0.021032 in Binomial test
# [[  0.  11.  12.  13.]
#  [  0.  11.  13.  12.]
#  [  0.  12.  11.  13.]
#  [  0.  12.  13.  11.]
#  [  0.  13.  11.  12.]
#  [  0.  13.  12.  11.]
#  [ 11.   0.  12.  13.]
#  [ 11.   0.  13.  12.]
#  [ 11.  12.   0.  13.]
#  [ 11.  12.  13.   0.]
#  [ 11.  13.   0.  12.]
#  [ 11.  13.  12.   0.]
#  [ 12.   0.  11.  13.]
#  [ 12.   0.  13.  11.]
#  [ 12.  11.   0.  13.]
#  [ 12.  11.  13.   0.]
#  [ 12.  13.   0.  11.]
#  [ 12.  13.  11.   0.]
#  [ 13.   0.  11.  12.]
#  [ 13.   0.  12.  11.]
#  [ 13.  11.   0.  12.]
#  [ 13.  11.  12.   0.]
#  [ 13.  12.   0.  11.]
#  [ 13.  12.  11.   0.]]
# [ 0.05555556  0.05555556  0.03452381  0.025       0.03452381  0.025
#   0.07063492  0.07063492  0.06309524  0.09642857  0.06309524  0.09642857
#   0.02103175  0.01547619  0.02896825  0.04404762  0.01507937  0.03015873
#   0.02103175  0.01547619  0.02896825  0.04404762  0.01507937  0.03015873]
# ###########################################################################
# [18  1  1  1 18 18  0  0 12]
# [ 1 18  0 12]
# with 1 repititions
# Significant with p-value 0.030159 in Binomial test
# [[  0.   1.  12.  18.]
#  [  0.   1.  18.  12.]
#  [  0.  12.   1.  18.]
#  [  0.  12.  18.   1.]
#  [  0.  18.   1.  12.]
#  [  0.  18.  12.   1.]
#  [  1.   0.  12.  18.]
#  [  1.   0.  18.  12.]
#  [  1.  12.   0.  18.]
#  [  1.  12.  18.   0.]
#  [  1.  18.   0.  12.]
#  [  1.  18.  12.   0.]
#  [ 12.   0.   1.  18.]
#  [ 12.   0.  18.   1.]
#  [ 12.   1.   0.  18.]
#  [ 12.   1.  18.   0.]
#  [ 12.  18.   0.   1.]
#  [ 12.  18.   1.   0.]
#  [ 18.   0.   1.  12.]
#  [ 18.   0.  12.   1.]
#  [ 18.   1.   0.  12.]
#  [ 18.   1.  12.   0.]
#  [ 18.  12.   0.   1.]
#  [ 18.  12.   1.   0.]]
# [ 0.06309524  0.09642857  0.07063492  0.07063492  0.09642857  0.06309524
#   0.02896825  0.04404762  0.02103175  0.01547619  0.03015873  0.01507937
#   0.05555556  0.05555556  0.03452381  0.025       0.03452381  0.025
#   0.04404762  0.02896825  0.03015873  0.01507937  0.02103175  0.01547619]
# ###########################################################################
# [11 11  0 12 20 20  0]
# [11  0 12 20]
# with 1 repititions
# Significant with p-value 0.038095 in Binomial test
# [[  0.  11.  12.  20.]
#  [  0.  11.  20.  12.]
#  [  0.  12.  11.  20.]
#  [  0.  12.  20.  11.]
#  [  0.  20.  11.  12.]
#  [  0.  20.  12.  11.]
#  [ 11.   0.  12.  20.]
#  [ 11.   0.  20.  12.]
#  [ 11.  12.   0.  20.]
#  [ 11.  12.  20.   0.]
#  [ 11.  20.   0.  12.]
#  [ 11.  20.  12.   0.]
#  [ 12.   0.  11.  20.]
#  [ 12.   0.  20.  11.]
#  [ 12.  11.   0.  20.]
#  [ 12.  11.  20.   0.]
#  [ 12.  20.   0.  11.]
#  [ 12.  20.  11.   0.]
#  [ 20.   0.  11.  12.]
#  [ 20.   0.  12.  11.]
#  [ 20.  11.   0.  12.]
#  [ 20.  11.  12.   0.]
#  [ 20.  12.   0.  11.]
#  [ 20.  12.  11.   0.]]
# [ 0.03809524  0.07619048  0.02857143  0.02857143  0.07619048  0.03809524
#   0.03809524  0.07619048  0.02857143  0.02857143  0.07619048  0.03809524
#   0.02380952  0.02380952  0.02380952  0.02380952  0.02380952  0.02380952
#   0.07619048  0.03809524  0.07619048  0.03809524  0.02857143  0.02857143]
# ###########################################################################
# [12 12 11 11 13 13 13 11 18 18]
# [12 11 13 18]
# with 1 repititions
# Significant with p-value 0.040714 in Binomial test
# [[ 11.  12.  13.  18.]
#  [ 11.  12.  18.  13.]
#  [ 11.  13.  12.  18.]
#  [ 11.  13.  18.  12.]
#  [ 11.  18.  12.  13.]
#  [ 11.  18.  13.  12.]
#  [ 12.  11.  13.  18.]
#  [ 12.  11.  18.  13.]
#  [ 12.  13.  11.  18.]
#  [ 12.  13.  18.  11.]
#  [ 12.  18.  11.  13.]
#  [ 12.  18.  13.  11.]
#  [ 13.  11.  12.  18.]
#  [ 13.  11.  18.  12.]
#  [ 13.  12.  11.  18.]
#  [ 13.  12.  18.  11.]
#  [ 13.  18.  11.  12.]
#  [ 13.  18.  12.  11.]
#  [ 18.  11.  12.  13.]
#  [ 18.  11.  13.  12.]
#  [ 18.  12.  11.  13.]
#  [ 18.  12.  13.  11.]
#  [ 18.  13.  11.  12.]
#  [ 18.  13.  12.  11.]]
# [ 0.01880952  0.02642857  0.01309524  0.01309524  0.02642857  0.01880952
#   0.04071429  0.05690476  0.04071429  0.05690476  0.09404762  0.09404762
#   0.01309524  0.01309524  0.01880952  0.02642857  0.01880952  0.02642857
#   0.05690476  0.04071429  0.09404762  0.09404762  0.04071429  0.05690476]
# ###########################################################################
# [12  6  6  1  9  9]
# [12  6  1  9]
# with 1 repititions
# Significant with p-value 0.022222 in Binomial test
# [[  1.   6.   9.  12.]
#  [  1.   6.  12.   9.]
#  [  1.   9.   6.  12.]
#  [  1.   9.  12.   6.]
#  [  1.  12.   6.   9.]
#  [  1.  12.   9.   6.]
#  [  6.   1.   9.  12.]
#  [  6.   1.  12.   9.]
#  [  6.   9.   1.  12.]
#  [  6.   9.  12.   1.]
#  [  6.  12.   1.   9.]
#  [  6.  12.   9.   1.]
#  [  9.   1.   6.  12.]
#  [  9.   1.  12.   6.]
#  [  9.   6.   1.  12.]
#  [  9.   6.  12.   1.]
#  [  9.  12.   1.   6.]
#  [  9.  12.   6.   1.]
#  [ 12.   1.   6.   9.]
#  [ 12.   1.   9.   6.]
#  [ 12.   6.   1.   9.]
#  [ 12.   6.   9.   1.]
#  [ 12.   9.   1.   6.]
#  [ 12.   9.   6.   1.]]
# [ 0.04444444  0.02222222  0.04444444  0.02222222  0.01666667  0.01666667
#   0.05555556  0.02777778  0.08333333  0.08333333  0.02777778  0.05555556
#   0.05555556  0.02777778  0.08333333  0.08333333  0.02777778  0.05555556
#   0.01666667  0.01666667  0.02222222  0.04444444  0.02222222  0.04444444]
# ###########################################################################
# [ 1 12 12 11 13 13 13 13 12]
# [ 1 12 11 13]
# with 1 repititions
# Significant with p-value 0.021429 in Binomial test
# [[  1.  11.  12.  13.]
#  [  1.  11.  13.  12.]
#  [  1.  12.  11.  13.]
#  [  1.  12.  13.  11.]
#  [  1.  13.  11.  12.]
#  [  1.  13.  12.  11.]
#  [ 11.   1.  12.  13.]
#  [ 11.   1.  13.  12.]
#  [ 11.  12.   1.  13.]
#  [ 11.  12.  13.   1.]
#  [ 11.  13.   1.  12.]
#  [ 11.  13.  12.   1.]
#  [ 12.   1.  11.  13.]
#  [ 12.   1.  13.  11.]
#  [ 12.  11.   1.  13.]
#  [ 12.  11.  13.   1.]
#  [ 12.  13.   1.  11.]
#  [ 12.  13.  11.   1.]
#  [ 13.   1.  11.  12.]
#  [ 13.   1.  12.  11.]
#  [ 13.  11.   1.  12.]
#  [ 13.  11.  12.   1.]
#  [ 13.  12.   1.  11.]
#  [ 13.  12.  11.   1.]]
# [ 0.025       0.04047619  0.02142857  0.05        0.04761905  0.07142857
#   0.025       0.04047619  0.02142857  0.05        0.04761905  0.07142857
#   0.01309524  0.03095238  0.01309524  0.03095238  0.0452381   0.0452381
#   0.03690476  0.05714286  0.03690476  0.05714286  0.06071429  0.06071429]
# ###########################################################################
# [13  0  0  0 13 13 13 13  9  9 12 12]
# [ 0 13  9 12]
# with 1 repititions
# Significant with p-value 0.014069 in Binomial test
# [[  0.   9.  12.  13.]
#  [  0.   9.  13.  12.]
#  [  0.  12.   9.  13.]
#  [  0.  12.  13.   9.]
#  [  0.  13.   9.  12.]
#  [  0.  13.  12.   9.]
#  [  9.   0.  12.  13.]
#  [  9.   0.  13.  12.]
#  [  9.  12.   0.  13.]
#  [  9.  12.  13.   0.]
#  [  9.  13.   0.  12.]
#  [  9.  13.  12.   0.]
#  [ 12.   0.   9.  13.]
#  [ 12.   0.  13.   9.]
#  [ 12.   9.   0.  13.]
#  [ 12.   9.  13.   0.]
#  [ 12.  13.   0.   9.]
#  [ 12.  13.   9.   0.]
#  [ 13.   0.   9.  12.]
#  [ 13.   0.  12.   9.]
#  [ 13.   9.   0.  12.]
#  [ 13.   9.  12.   0.]
#  [ 13.  12.   0.   9.]
#  [ 13.  12.   9.   0.]]
# [ 0.02532468  0.02121212  0.02532468  0.02121212  0.01406926  0.01406926
#   0.054329    0.04588745  0.08917749  0.10497835  0.04220779  0.05735931
#   0.054329    0.04588745  0.08917749  0.10497835  0.04220779  0.05735931
#   0.01082251  0.01082251  0.01471861  0.01991342  0.01471861  0.01991342]
# ###########################################################################
# [12 12 12 12 12 12  0  1 11 11]
# [12  0  1 11]
# with 1 repititions
# Significant with p-value 0.013889 in Binomial test
# [[  0.   1.  11.  12.]
#  [  0.   1.  12.  11.]
#  [  0.  11.   1.  12.]
#  [  0.  11.  12.   1.]
#  [  0.  12.   1.  11.]
#  [  0.  12.  11.   1.]
#  [  1.   0.  11.  12.]
#  [  1.   0.  12.  11.]
#  [  1.  11.   0.  12.]
#  [  1.  11.  12.   0.]
#  [  1.  12.   0.  11.]
#  [  1.  12.  11.   0.]
#  [ 11.   0.   1.  12.]
#  [ 11.   0.  12.   1.]
#  [ 11.   1.   0.  12.]
#  [ 11.   1.  12.   0.]
#  [ 11.  12.   0.   1.]
#  [ 11.  12.   1.   0.]
#  [ 12.   0.   1.  11.]
#  [ 12.   0.  11.   1.]
#  [ 12.   1.   0.  11.]
#  [ 12.   1.  11.   0.]
#  [ 12.  11.   0.   1.]
#  [ 12.  11.   1.   0.]]
# [ 0.0218254   0.02380952  0.02777778  0.06349206  0.02380952  0.04761905
#   0.0218254   0.02380952  0.02777778  0.06349206  0.02380952  0.04761905
#   0.03373016  0.07936508  0.03373016  0.07936508  0.0952381   0.0952381
#   0.01388889  0.02777778  0.01388889  0.02777778  0.04166667  0.04166667]
# ###########################################################################

# %%
pl.hist(sigVec);
pkl.dump(sigSeqz,open('sigSeqz04.sqz','wb'),pkl.HIGHEST_PROTOCOL)

# %%
sigIndex = np.where(sigVec < 0.05)[0]
float(sigIndex.size) / sigVec.size * 100
# Out:
# 64.86486486486487

# %%
leftFields = np.array([ 6,  9, 10, 11,  1,  0, 18, 12, 13, 20])
rightFields = np.array([19,  6,  9, 10,  8, 11,  0, 20,  1, 18, 12, 13])

# %%
PLrankCorrL = []
for item in sigSeqz:
    corrPL =  scipy.stats.pearsonr(subsequence(item,leftFields)[0],sorted(subsequence(item,leftFields)[0]))
    PLrankCorrL.append(corrPL)

# %%
pl.hist(np.array(PLrankCorrL)[:,0]);

# %%
for item in sigSeqz:
    corrPL =  scipy.stats.pearsonr(subsequence(item,rightFields)[0],range(4))
    if corrPL[1] < 0.1:
        print item
        print subsequence(item,rightFields)
        print corrPL
        print '**************'
# Out:
# [ 6  9 10  1]
# (array([1, 2, 3, 8]), True)
# (0.91350027839113968, 0.086499721608860325)
# **************

# %%
6/float(np.where(sigVec < 0.05)[0].size)
# Out:
# 0.24

# %%
k = 1
x = np.array([1, 2, 3, 8])
while next_permutation(x[::-1]):
    k+=1
print 24-k
# Out:
# 23

# %%
SiglexicographicalRanksL = []
SiglexicographicalRanksR = []
for item in np.array(sigSeqz)[sigIndex]:
    Lrank = subsequence(item,leftFields)[0]
    Rrank = subsequence(item,rightFields)[0]
    lexiRankL = 1
    lexiRankR = 1
    while next_permutation(Lrank):
        lexiRankL +=1
    SiglexicographicalRanksL.append(24 - lexiRankL)
    while next_permutation(Rrank):
        lexiRankR +=1
    SiglexicographicalRanksR.append(24 - lexiRankR)

# %%
lexicographicalRanksL = []
lexicographicalRanksR = []
for item in sigSeqz:
    Lrank = subsequence(item,leftFields)[0]
    Rrank = subsequence(item,rightFields)[0]
    lexiRankL = 1
    lexiRankR = 1
    while next_permutation(Lrank):
        lexiRankL +=1
    lexicographicalRanksL.append(24 - lexiRankL)
    while next_permutation(Rrank):
        lexiRankR +=1
    lexicographicalRanksR.append(24 - lexiRankR)

# %%
f,ax = pl.subplots(1,2,figsize = [20,5])
ax[0].hist([lexicographicalRanksR,SiglexicographicalRanksR,],np.arange(-0.5,24.5),normed=False)
ax[1].hist([lexicographicalRanksL,SiglexicographicalRanksL,surrogage],np.arange(-0.5,24.5),normed=True);
ax[0].set_title('Right')
ax[1].set_title('Left')
ax[0].set_xticks(range(0,24));
ax[1].set_xticks(range(0,24));
ax[0].set_xlim([-1,24]);
ax[1].set_xlim([-1,24]);

# %%
surrogate = np.choose

# %%
lexHistAllRight= np.histogram(lexicographicalRanksR,np.arange(-0.5,25.5))
lexHistSigRight = np.histogram(SiglexicographicalRanksR,np.arange(-0.5,25.5))

lexHistAllLeft= np.histogram(lexicographicalRanksL,np.arange(-0.5,25.5))
lexHistSigLeft = np.histogram(SiglexicographicalRanksL,np.arange(-0.5,25.5))


RsigPercent = []
for ii,item in enumerate(lexHistAllRight[0]):
    if lexHistAllRight[0][ii] == 0:
        if lexHistSigRight[0][ii] == 0:
            RsigPercent.append(0.0)
    else:
        RsigPercent.append(float(lexHistSigRight[0][ii])/lexHistAllRight[0][ii] * 100)

        
LsigPercent = []
for ii,item in enumerate(lexHistAllLeft[0]):
    if lexHistAllLeft[0][ii] == 0:
        if lexHistSigLeft[0][ii] == 0:
            LsigPercent.append(0.0)
    else:
        LsigPercent.append(float(lexHistSigLeft[0][ii])/lexHistAllLeft[0][ii] *100 )

# %%
pl.bar(range(0,25),LsigPercent,width=0.4)
#pl.bar(np.arange(0.4,25.4),RsigPercent,width=0.4,color='y')
pl.legend(['L','R'])

# %%
surrogage = np.random.choice(range(24),500000,)

# %%
pl.hist(surrogage,normed=True);

# %%
sessionPath = '/media/chenani/Data/ephysdata/Rats/MECLesion/Rat616Control/2013-06-02_07-42-38/sleep2/'
lexNormedL = np.array(lexicographicalRanksL)/float(np.math.factorial(n))
lexNormedR = np.array(lexicographicalRanksR)/float(np.math.factorial(n))
pkl.dump(lexNormedL,open(sessionPath+'lexRanks/lexNormed_L_'+str(n)+'.lex','wb'),pkl.HIGHEST_PROTOCOL)
pkl.dump(lexNormedR,open(sessionPath+'lexRanks/lexNormed_R_'+str(n)+'.lex','wb'),pkl.HIGHEST_PROTOCOL)

# %%
pl.hist(lexNormedR,normed=True)
# Out:
# (array([ 1.47420147,  1.17936118,  0.88452088,  0.88452088,  0.58968059,
#          1.47420147,  0.88452088,  1.47420147,  0.58968059,  1.47420147]),
#  array([ 0.        ,  0.09166667,  0.18333333,  0.275     ,  0.36666667,
#          0.45833333,  0.55      ,  0.64166667,  0.73333333,  0.825     ,
#          0.91666667]),
#  <a list of 10 Patch objects>)
