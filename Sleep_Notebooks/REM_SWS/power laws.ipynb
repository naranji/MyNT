# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt4Agg

# %%
cd /media/chenani/Data/Workspaces/Eclipse/dataAnalysis/Sleep-current/src/
# Out:
# /media/chenani/Data/Workspaces/Eclipse/dataAnalysis/Sleep-current/src

# %%
import numpy as np
import matplotlib.pyplot as pl
from extras import trees
import pickle as pkl
import signale

# %%
dataPath = '/home/chenani/dataWork/josephine/10353/real/2014-06-11_real/'
animals = []

# %%
for item in trees.locate("*r*.ephys",dataPath):
    ephysFile =  item[0]+'/'+item[1]
    
ephysFile
# Out:
# '/home/chenani/dataWork/josephine/10353/real/2014-06-11_real/linTrack1/linTrack1.ephys'

# %%
rec = pkl.load(open(ephysFile,'rb'))

# %%
rec.LFPs.plot()
# Out:
# (<matplotlib.figure.Figure at 0x7f25dfab5990>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f25dfaaf950>)

# %%
lfp = rec.LFPs[0]

# %%
1/ lfp.dt * 1000
# Out:
# 2034.0000000000002

# %%
lfp.duration()/60000
# Out:
# 16.94080629301868

# %%
print lfp.header
# Out:
# ######## Neuralynx Data File Header
# ## File Name: C:\User\josephine\10353\2014-06-11_12-40-03\06. linTrack1 To Stopping Recording\CSC1.ncs
# ## Time Opened: (m/d/y): 6/11/2014 At Time: 13:47:54.906
# 	-FileType	CSC
# 	-FileVersion	3.3.0
# 	-RecordSize	1044
# 	-CheetahRev	5.6.3
# 	-HardwareSubSystemName	AcqSystem1
# 	-HardwareSubSystemType	DigitalLynx
# 	-SamplingFrequency	2034.75
# 	-ADMaxValue	32767
# 	-ADBitVolts	0.000000045777763801879701
# 	-AcqEntName	CSC1
# 	-NumADChannels	1
# 	-ADChannel	32
# 	-InputRange	1500
# 	-InputInverted	True
# 	-DSPLowCutFilterEnabled	True
# 	-DspLowCutFrequency	1
# 	-DspLowCutNumTaps	0
# 	-DspLowCutFilterType	DCO
# 	-DSPHighCutFilterEnabled	True
# 	-DspHighCutFrequency	500
# 	-DspHighCutNumTaps	64
# 	-DspHighCutFilterType	FIR
# 	-DspDelayCompensation	Disabled
# 	-DspFilterDelay_�s	968

# %%
import binascii
#binascii.unhexlify()
print lfp.header[:797].decode()
print lfp.header[799:].decode()
# Out:
# ######## Neuralynx Data File Header
# ## File Name: C:\User\josephine\10353\2014-06-11_12-40-03\06. linTrack1 To Stopping Recording\CSC1.ncs
# ## Time Opened: (m/d/y): 6/11/2014 At Time: 13:47:54.906
# 	-FileType	CSC
# 	-FileVersion	3.3.0
# 	-RecordSize	1044
# 	-CheetahRev	5.6.3
# 	-HardwareSubSystemName	AcqSystem1
# 	-HardwareSubSystemType	DigitalLynx
# 	-SamplingFrequency	2034.75
# 	-ADMaxValue	32767
# 	-ADBitVolts	0.000000045777763801879701
# 	-AcqEntName	CSC1
# 	-NumADChannels	1
# 	-ADChannel	32
# 	-InputRange	1500
# 	-InputInverted	True
# 	-DSPLowCutFilterEnabled	True
# 	-DspLowCutFrequency	1
# 	-DspLowCutNumTaps	0
# 	-DspLowCutFilterType	DCO
# 	-DSPHighCutFilterEnabled	True
# 	-DspHighCutFrequency	500
# 	-DspHighCutNumTaps	64
# 	-DspHighCutFilterType	FIR
# 	-DspDelayCompensation	Disabled
# 	-DspFilterDelay
# s	968

# %%
signale.load_ncsFile(dataPath,showHeader=True)
# Out:
# ######## Neuralynx Data File Header
# ## File Name: C:\User\josephine\10353\2014-06-11_12-40-03\03. sleep To Stopping Recording\CSC1.ncs
# ## Time Opened: (m/d/y): 6/11/2014 At Time: 13:47:54.859
# 	-FileType	CSC
# 	-FileVersion	3.3.0
# 	-RecordSize	1044
# 	-CheetahRev	5.6.3
# 	-HardwareSubSystemName	AcqSystem1
# 	-HardwareSubSystemType	DigitalLynx
# 	-SamplingFrequency	2034.75
# 	-ADMaxValue	32767
# 	-ADBitVolts	0.000000045777763801879701
# 	-AcqEntName	CSC1
# 	-NumADChannels	1
# 	-ADChannel	32
# 	-InputRange	1500
# 	-InputInverted	True
# 	-DSPLowCutFilterEnabled	True
# 	-DspLowCutFrequency	1
# 	-DspLowCutNumTaps	0
# 	-DspLowCutFilterType	DCO
# 	-DSPHighCutFilterEnabled	True
# 	-DspHighCutFrequency	500
# 	-DspHighCutNumTaps	64
# 	-DspHighCutFilterType	FIR
# 	-DspDelayCompensation	Disabled
# 	-DspFilterDelay_�s	968
#
# ----> count 0
# 974409609
# 0
# 2034
# 512
# (512,)
#
# WARNING: Not all records are contiguous. Packets lost?

# %%
1/0.000000045777763801879701
# Out:
# 21844666.863324124

# %%
1500/0.000000045777763801879701
# Out:
# 32767000294.986183
